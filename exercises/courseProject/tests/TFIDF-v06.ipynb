# %%
### imports
import import_ipynb
import readingAndPreprocessingInput as rp

import pandas as pd
import math 

from sklearn.feature_extraction.text import TfidfVectorizer

# from sklearn.feature_extraction.text import TfidfTransformer
# from sklearn.feature_extraction.text import CountVectorizer

# %%
### create a bag of words 
def createBagsOfWOrds(corpus):
    bagOfWordsTitle = []
    bagOfWordsCaption = []
    for doc in corpus:
        for term in doc['articleTitle']:
            if term not in bagOfWordsTitle:
                bagOfWordsTitle.append(term)
        for cap in doc['caption']:
            for term in cap:
                if term not in bagOfWordsCaption:
                    bagOfWordsCaption.append(term)
    
    return bagOfWordsTitle, bagOfWordsCaption

bagOfWordsTitle, bagOfWordsCaption = createBagsOfWOrds(rp.cleanedDocs)

print(bagOfWordsTitle[:10])#, bagOfWordsCaption[:10])
print(len(bagOfWordsTitle))
print(len(bagOfWordsCaption))
# Out:
# ['neoadjuvant', 'lenvatinib', 'advanced', 'unresectable', 'medullary', 'thyroid', 'carcinoma', 'case', 'report', 'spontaneous']
# 456
# 2510

# %%
bow = set(bagOfWordsTitle).union(set(bagOfWordsCaption))
print(len(bow))
# Out:
# 2669

# %%
def computeCaptionTFIDF(docList):
    vectorizer = TfidfVectorizer(lowercase = False, tokenizer = rp.preprocessContent)
    totalDenseList = []
    totalFeatureNames = []
    feature_names = []
    vectors = []
    for j, doc in enumerate(docList):
        vector = vectorizer.fit_transform(doc)
        featureNames = vectorizer.get_feature_names()
#         print("docID: " + str(j))
#         print(featureNames)
#         print("_______________________")
#         df = pd.DataFrame(vector, columns=featureNames)
    vectors.append(vector)
    feature_names.append(featureNames)
#     dense = vectors.todense()
#     denselist = dense.tolist()
        
#         totalFeatureNames.append(feature_names)
#         totalDenseList.append(denselist)
#     df = pd.DataFrame(vectors, columns=feature_names)
    return vectors, feature_names

# title_tfidf, title_df = computeTFIDF(titlesList)
print(captionsList[0][1])
caption_tfidf, caption_df = computeCaptionTFIDF(captionsList)
# caption_tfidf
# Out:
# Sagittal contrast-enhanced computed tomography scans prelenvatinib (left) and 4 months postlenvatinib therapy (right). Note the marked reduction in radiodensity (165.05 HU versus 61.54 HU) suggesting devascularization of the tumor. HU = Hounsfield unit.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-92-57c1a585d63b> in <module>()
#      26 # title_tfidf, title_df = computeTFIDF(titlesList)
#      27 print(captionsList[0][1])
# ---> 28 caption_tfidf, caption_df = computeCaptionTFIDF(captionsList)
#      29 # caption_tfidf
#
# <ipython-input-92-57c1a585d63b> in computeCaptionTFIDF(docList)
#      13 #         df = pd.DataFrame(vector, columns=featureNames)
#      14     vectors.append(vector)
# ---> 15     print(len(vectors[1]))
#      16     print("_______________________")
#      17     feature_names.append(featureNames)
#
# IndexError: list index out of range

# %%
def computeTFIDF(docList):
    vectorizer = TfidfVectorizer(lowercase = False, tokenizer = rp.preprocessContent)
    vectors = vectorizer.fit_transform(docList)
#     print(vectors)
    feature_names = vectorizer.get_feature_names()
    dense = vectors.todense()
    denselist = dense.tolist()
    df = pd.DataFrame(denselist, columns=feature_names)
    return denselist, feature_names, df

title_tfidf, title_terms, title_df = computeTFIDF(titlesList)

# %%
# print(title_tfidf[0])
# print(title_tfidf[0][8])
print(title_terms)
title_df
# Out:
# ['175', '3a4', '550', 'absorption', 'acquired', 'additional', 'adrenal', 'adults', 'advanced', 'advancing', 'aerosolisation', 'age', 'agonist', 'allow', 'amiodarone', 'amorphous', 'analysis', 'anaphylaxis', 'animals', 'anion', 'anti', 'antibiotic', 'antibodies', 'antibody', 'antiphospholipid', 'antiviral', 'approach', 'aspects', 'assays', 'assignment', 'assignments', 'associated', 'attrition', 'average', 'balance', 'based', 'bayesian', 'bddcs', 'bilateral', 'binding', 'bioequivalence', 'biological', 'biomarker', 'biotechnology', 'biowaiver', 'blood', 'body', 'breast', 'bridge', 'cancer', 'cannabinoids', 'carcinoma', 'carcinomatosis', 'cardiomyopathy', 'case', 'caused', 'celecoxib', 'cell', 'cells', 'censoring', 'centella', 'cerebral', 'cerebrospinal', 'change', 'chemical', 'chemoradiotherapy', 'children', 'circadian', 'circannual', 'classification', 'clinical', 'colistin', 'combination', 'combined', 'complex', 'composition', 'conditions', 'conference', 'confers', 'congenital', 'consisting', 'copolymer', 'correcting', 'corrections', 'correlation', 'crisis', 'cushing', 'cycle', 'cytochrome', 'cytoreductive', 'dasabuvir', 'data', 'days', 'death', 'deconvolution', 'deficiency', 'degradation', 'delivery', 'dependent', 'development', 'diabetes', 'diagnosis', 'dietary', 'digestion', 'dilated', 'discovery', 'disease', 'dispersion', 'dispersions', 'dissolution', 'docetaxel', 'docking', 'dopamine', 'dosage', 'doxorubicin', 'dried', 'drug', 'drugs', 'ductal', 'dwarfism', 'dynamics', 'early', 'earth', 'effect', 'effective', 'effects', 'elucidate', 'empirical', 'enhanced', 'enlarging', 'erythropoiesis', 'estimations', 'evaluate', 'evaluating', 'evaluation', 'evidence', 'exact', 'exchange', 'exendin', 'expanding', 'exploring', 'expression', 'extended', 'extract', 'familial', 'fat', 'fda', 'fdu', 'features', 'filtration', 'fit', 'fluid', 'follicular', 'followed', 'forms', 'formulation', 'fub', 'gefitinib', 'gender', 'generalized', 'genetic', 'genotype', 'glomerular', 'glucagonoma', 'goiter', 'gold', 'gomisin', 'gper', 'growth', 'half', 'halofantrine', 'handle', 'hashimoto', 'hcv', 'healthy', 'heart', 'hemorrhage', 'hepatitis', 'hepcidin', 'hereditary', 'human', 'humans', 'hydrogel', 'hydrogels', 'hypercortisolism', 'hyperthermic', 'hyperthyroidism', 'hypogonadal', 'hypothyroidism', 'ige', 'immune', 'immunity', 'immunogenic', 'immunogenicity', 'impact', 'impacts', 'implementation', 'improvement', 'induced', 'induction', 'infant', 'infants', 'infection', 'inflammation', 'influence', 'inhaled', 'inhibition', 'initiation', 'injectable', 'insufficiency', 'insulin', 'integrated', 'interactions', 'international', 'interval', 'intranasal', 'intraperitoneal', 'intratumoural', 'invasive', 'iodine', 'iron', 'ischemia', 'isoform', 'ivivc', 'joint', 'leak', 'lenvatinib', 'life', 'ligand', 'ligands', 'limiting', 'line', 'lipid', 'lipodystrophy', 'literature', 'liver', 'living', 'lmna', 'load', 'loaded', 'long', 'loss', 'macromolecular', 'macroprolactinomas', 'male', 'males', 'malignant', 'manifestations', 'mass', 'materials', 'mathematical', 'measurement', 'medications', 'medullary', 'melanoma', 'menstrual', 'metabolism', 'metabolites', 'metastatic', 'method', 'mice', 'microcentrifuge', 'microcephalic', 'microsomes', 'model', 'modeling', 'modelling', 'models', 'modulating', 'monoclonal', 'morphine', 'mouse', 'multiplex', 'mutations', 'myelolipoma', 'nanoemulsifying', 'nanoparticles', 'nanostructured', 'need', 'nelson', 'neoadjuvant', 'neonatal', 'neonates', 'neuroprotective', 'nonautoimmune', 'novel', 'omalizumab', 'ombitasvir', 'oral', 'organic', 'oxaliplatin', 'p450', 'painful', 'paradigm', 'parameter', 'paritaprevir', 'patient', 'patients', 'pattern', 'pembrolizumab', 'pentablock', 'performance', 'peritoneal', 'perspective', 'pharma', 'pharmacodynamic', 'pharmacokinetic', 'pharmacokinetics', 'pharmacology', 'phase', 'phenotype', 'phenotypes', 'phospholipid', 'physiologically', 'phytoconstituents', 'pituitary', 'plasma', 'platelet', 'population', 'poten ...
#          175       3a4       550  absorption  acquired  additional   adrenal  \
# 0   0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 1   0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 2   0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 3   0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 4   0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 5   0.000000  0.000000  0.000000    0.000000  0.338147    0.000000  0.000000
# 6   0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 7   0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.564585
# 8   0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.508968
# 9   0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 10  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 11  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 12  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 13  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 14  0.225598  0.000000  0.000000    0.000000  0.000000    0.225598  0.000000
# 15  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 16  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 17  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 18  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 19  0.000000  0.000000  0.290813    0.000000  0.000000    0.000000  0.000000
# 20  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 21  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 22  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 23  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 24  0.000000  0.268024  0.000000    0.000000  0.000000    0.000000  0.000000
# 25  0.000000  0.000000  0.000000    0.307351  0.000000    0.000000  0.000000
# 26  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 27  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 28  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 29  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 30  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 31  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 32  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 33  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 34  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 35  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 36  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 37  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 38  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 39  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 40  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 41  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 42  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 43  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 44  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 45  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 46  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 47  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 48  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 49  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 50  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 51  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 52  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 53  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 54  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 55  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 56  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.303361
# 57  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
# 58  0.000000  0.000000  0.000000    0.000000  0.000000    0.000000  0.000000
#
#      adults  advanced  advancing    ...     vignette    virals     virus  \
# 0   0.00000   0.34897   0.000000    ...     0.000000  0.000000  0.000000
# 1   0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 2   0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 3   0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 4   0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 5   0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 6   0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 7   0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 8   0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 9   0.00000   0.00000   0.000000    ...     0.343986  0.343986  0.000000
# 10  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 11  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 12  0.00000   0.00000   0.357502    ...     0.000000  0.000000  0.000000
# 13  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 14  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 15  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.262176
# 16  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 17  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 18  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 19  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 20  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 21  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 22  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 23  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 24  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 25  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 26  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 27  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 28  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 29  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 30  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 31  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 32  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 33  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 34  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 35  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 36  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 37  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 38  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 39  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 40  0.28299   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 41  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 42  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 43  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 44  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 45  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 46  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 47  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 48  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 49  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 50  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 51  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 52  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 53  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 54  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 55  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 56  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 57  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
# 58  0.00000   0.00000   0.000000    ...     0.000000  0.000000  0.000000
#
#        vitro      vivo     whole     women  xenografted      xrcc     young
# 0   0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.325270  0.000000     0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.305962  0.000000     0.000000  0.000000  0.000000
# 22  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 26  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 27  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 28  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.315595
# 29  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 30  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 31  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 32  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 33  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 34  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 35  0.000000  0.000000  0.000000  0.364863     0.000000  0.000000  0.000000
# 36  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 37  0.303914  0.323374  0.000000  0.000000     0.000000  0.000000  0.000000
# 38  0.303914  0.323374  0.000000  0.000000     0.000000  0.000000  0.000000
# 39  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 40  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 41  0.257467  0.273953  0.000000  0.000000     0.000000  0.000000  0.000000
# 42  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 43  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 44  0.000000  0.000000  0.000000  0.000000     0.244221  0.000000  0.000000
# 45  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 46  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 47  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 48  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 49  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 50  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 51  0.203900  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 52  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 53  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 54  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.248399
# 55  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 56  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 57  0.000000  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# 58  0.000000  0.000000  0.000000  0.000000     0.000000  0.443968  0.000000
#
# [59 rows x 456 columns]
