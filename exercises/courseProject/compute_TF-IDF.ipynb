# %%
### imports
import import_ipynb
import readingAndPreprocessingInput as rp

import pandas as pd
import math

# %%
bow = set(rp.bagOfWordsTitle).union(set(rp.bagOfWordsCaption))
print(len(bow))
# Out:
# 2587

# %%
### for a given document (title or caption) computes the term frequency 
### returns dictionary with all terms from all documents for keys and TF for the values
def computeTFperDoc(doc, bow):
    termsDict = dict.fromkeys(bow, 0)
    n = len(doc)
    for term in doc:
        termsDict[term] = doc.count(term)/n
    return termsDict

termsDict = computeTFperDoc(rp.cleanedDocs[0]['caption'][0], bow)
# print(len(termsDict))
# print(termsDict)
df1 = pd.DataFrame.from_dict(termsDict, orient='index')
df1.sort_values(by=[0], ascending=False)
# Out:
#                               0
# therapy                0.076923
# months                 0.051282
# cea                    0.051282
# trachea                0.051282
# surgery                0.025641
# note                   0.025641
# prelenvatinib          0.025641
# timeline               0.025641
# invasion               0.025641
# concentrations         0.025641
# contrast               0.025641
# lenvatinib             0.025641
# ultrasound             0.025641
# mass                   0.025641
# calcitonin             0.025641
# tomography             0.025641
# postlenvatinib         0.025641
# potential              0.025641
# encirclement           0.025641
# antigen                0.025641
# axial                  0.025641
# enhanced               0.025641
# computed               0.025641
# carcinoembryonic       0.025641
# scans                  0.025641
# prior                  0.025641
# post                   0.025641
# versus                 0.025641
# ...

# %%
### TF - the number of times a term appears in a document/ devided by the total number of terms in that document

def computeTF(corpus,bow):
    
#     bagOfWordsTitle, bagOfWordsCaption = createBagsOfWOrds(rp.cleanedDocs)
#     bow = set(bagOfWordsTitle).union(set(bagOfWordsCaption))
    title_tf = []
    caption_tf = []
    for doc in corpus:
        title_tf.append(computeTFperDoc(doc['articleTitle'], bow))
        for cap in doc['caption']:
            caption_tf.append(computeTFperDoc(cap, bow))
    return title_tf, caption_tf
    
title_tf, caption_tf = computeTF(rp.cleanedDocs,bow)
print(len(title_tf))
print(len(caption_tf))

# print(title_tf[0]['case'])
# print(title_tf[1]['case'])
# print(title_tf[2]['case'])
# print(title_tf[3]['case'])
# print(title_tf[4])
# Out:
# 59
# 263

# %%
# df = pd.DataFrame(title_tf)
# df.sort_values(by=['young'], axis=0,ascending=False)
# df
# print(title_tf[0])

# %%
# print(caption_tf[0])
# df = pd.DataFrame.from_dict(caption_tf)
# df

# %%
### computes the idf for all the terms in the 'Bag of words' from all docs
import math
def computeIDF(corpus, bow):
    titleN = len(corpus)
    captionN = 0
#     bagOfWordsTitle, bagOfWordsCaption = createBagsOfWOrds(rp.cleanedDocs)
#     bow = set(bagOfWordsTitle).union(set(bagOfWordsCaption))
    
    title_idfDict = dict.fromkeys(bow,[])
    caption_idfDict = dict.fromkeys(bow,[])
    for i,doc in enumerate(corpus):
        for term in doc['articleTitle']:
            if len(title_idfDict[term]) > 0:  ### term in doc['articleTitle'] :
                title_idfDict[term].append((i,'t')) 
            else:
                title_idfDict[term] = [(i,'t')]
        for j, cap in enumerate(doc['caption']):
            captionN += 1
            for term in cap:
                if len(caption_idfDict[term]) > 0:
                    caption_idfDict[term].append((i,j,'c'))
                else:
                    caption_idfDict[term] = [(i,j,'c')]
                    
    for term in title_idfDict:
        title_idfDict[term] = math.log10(titleN/(len(title_idfDict[term])+1))
    for term in caption_idfDict:
        caption_idfDict[term] = math.log10(captionN/(len(caption_idfDict[term])+1))
        
    return title_idfDict, caption_idfDict

title_idfDict, caption_idfDict = computeIDF(rp.cleanedDocs, bow)
# print(len(title_idfDict))
# print(title_idfDict)
# print(caption_idfDict['case'])

# %%
# df = pd.DataFrame(list(title_idfDict.items()))
# df
# print(title_idfDict.keys())

# %%
# df = pd.DataFrame(list(caption_idfDict.items()))
# df

# %%
# print((title_tf[0]['located']))
# print((title_idfDict.keys()))
# i=0
# for term in title_idfDict.keys():
#     if title_tf[0][term] > 0:
#         print(str(i)+" = " + term + " - " + str(title_tf[0][term]))
#         i+=1

# %%
### computes the TF-IDF weight by given tfs and idfs for the terms in all docs (titles and captions)
def computeTFIDF(tfs,idfs, bow):
#     bagOfWordsTitle, bagOfWordsCaption = createBagsOfWOrds(rp.cleanedDocs)
#     bow = set(bagOfWordsTitle).union(set(bagOfWordsCaption))
    
    tfidf_dict = [] 
    n = len(tfs)
    
    for i in range(n):
        tfidf_doc = dict.fromkeys(bow,0)
        for term in idfs.keys():
#              print(term, tfs[i][term], idfs[term])
            tfidf_doc[term] = tfs[i][term]*idfs[term]
        tfidf_dict.append(tfidf_doc)
    return tfidf_dict

title_tfidf = computeTFIDF(title_tf, title_idfDict, bow)
df = pd.DataFrame(list(title_tfidf))
# df

# %%
caption_tfidf = computeTFIDF(caption_tf, caption_idfDict,bow)
df = pd.DataFrame(list(caption_tfidf))
# df
# caption_tfidf[0]

# %%
### computes the final TF-IDF weijght for each term by the formula:
### TF-IDF weight = alpha * title_tfidf + (1-alpha)caption_tfidf

def mergeTFIDFtables(alpha):
    tfidf = []
    title_tfidf = computeTFIDF(title_tf, title_idfDict, bow)
    caption_tfidf = computeTFIDF(caption_tf, caption_idfDict, bow)
    captions_dict = rp.capDicts(rp.cleanedDocs)
    n = len(caption_tfidf)
    m = len(title_tfidf)
    doc_idx = 0 
    for i in range(n-1):
        doc_tfidf =  dict.fromkeys(bow,0)
        
        for term in bow:
            doc_tfidf[term] = alpha*caption_tfidf[i][term] + title_tfidf[captions_dict[i]][term]*(1-alpha)
        
        tfidf.append(doc_tfidf)
    
    return tfidf
            
finalTFIDF = mergeTFIDFtables(0.3)

# print(finalTFIDF)
    
print

# %%
df = pd.DataFrame((finalTFIDF))
df
# df_tfidf = pd.DataFrame.from_dict(finalTFIDF, orient='index')
# df_tfidf.sort_values(by=[0], ascending=False)
# Out:
#      aaa  abbreviations   abdomen  abdominal  abel  ability  able  abnormal  \
# 0    0.0       0.000000  0.000000    0.00000   0.0      0.0   0.0  0.000000
# 1    0.0       0.000000  0.000000    0.00000   0.0      0.0   0.0  0.000000
# 2    0.0       0.000000  0.000000    0.00000   0.0      0.0   0.0  0.000000
# 3    0.0       0.000000  0.000000    0.00000   0.0      0.0   0.0  0.000000
# 4    0.0       0.000000  0.000000    0.00000   0.0      0.0   0.0  0.000000
# 5    0.0       0.000000  0.000000    0.00000   0.0      0.0   0.0  0.000000
# 6    0.0       0.000000  0.000000    0.00000   0.0      0.0   0.0  0.000000
# 7    0.0       0.000000  0.000000    0.00000   0.0      0.0   0.0  0.000000
# 8    0.0       0.000000  0.000000    0.00000   0.0      0.0   0.0  0.000000
# 9    0.0       0.000000  0.000000    0.00000   0.0      0.0   0.0  0.000000
# 10   0.0       0.000000  0.000000    0.00000   0.0      0.0   0.0  0.000000
# ...

# %%
# df = pd.DataFrame((finalTFIDF[0]),)
# df
df1 = pd.DataFrame.from_dict(finalTFIDF[0], orient='index')
df1.sort_values(by=[0], ascending=False)
# Out:
#                               0
# lenvatinib             0.130619
# advanced               0.114319
# medullary              0.114319
# report                 0.114319
# unresectable           0.114319
# neoadjuvant            0.114319
# thyroid                0.112292
# carcinoma              0.100624
# case                   0.077210
# therapy                0.036343
# trachea                0.029890
# cea                    0.029890
# months                 0.019597
# carcinoembryonic       0.016299
# esophageal             0.016299
# invasion               0.016299
# membranous             0.016299
# calcitonin             0.016299
# encirclement           0.016299
# antigen                0.016299
# postlenvatinib         0.014945
# timeline               0.014945
# prelenvatinib          0.014945
# scans                  0.014945
# enhanced               0.014945
# surgery                0.013984
# degree                 0.013984
# potential              0.013984
# ...
