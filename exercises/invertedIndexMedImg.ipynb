# %%
### a method to Read a json file with img captions and article titles and parse it into set of documents

import json

def getDocs(sourcePath):
    medDocs = []
    sourceFile = open(sourcePath, 'r')

    count = 1
    for line in sourceFile:
        medDocs.append(json.loads(line))
        count += 1

    sourceFile.close()
    
    # for k in range(1,count):
    #     print(str(k) + " : " + medDocs[k]['docId'])
    return medDocs


sourcePath = 'assets/medImages.jl'
medDocs = getDocs(sourcePath)
medDocs[262]
# Out:
# {'articleId': 'PMC7282154',
#  'image_path': 'PMC7282154-6_i2376-0605-6-2-e50-f06.jpg',
#  'image_url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7282154/bin/i2376-0605-6-2-e50-f06.jpg',
#  'articleUrl': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7282154/',
#  'articleTitle': 'RECURRENT INVASIVE DUCTAL BREAST CARCINOMA PRESENTING AS PRIMARY ADRENAL INSUFFICIENCY WITH ADRENAL CRISIS',
#  'caption': 'Histologic section of adrenal metastatic disease (hematoxylin and eosin, Г—100). Tumor cells arranged in solid nests infiltrating lymph node tissue.'}

# %%
from nltk.tokenize import sent_tokenize, TweetTokenizer
from string import punctuation
import re
import regex
tokenizer = TweetTokenizer()
#from nltk.corpus import stopwords
#nltk.download('stopwords')


# Returns a list of tokens for a document's content. Tokens should not contain punctuation and should be lower-cased.
    
def preprocessContent(content):
    sentences = sent_tokenize(content)
    tokens = []
    for sent in sentences:
        remNumb = re.sub('[0-9]+', '', sent)
        remParantese = regex.sub(r'\([^()]*+(?:(?R)[^()]*)*+\)', '', remNumb) 
        remParantese2 = regex.sub('\{(?:[^}{]|\{[^}{]*\})*\}', '', remParantese) 
        remTags = re.sub('\<+/*\w*/*\>+', '', remParantese2)
        sentTokens = tokenizer.tokenize(remTags)
        sentTokens = [tok.lower() for tok in sentTokens if not tok in punctuation and len(tok) > 2] # and tok not in stopwords.words('english')]
        #sentTokens = 
        tokens += sentTokens
    return tokens


def getTerms(medDocs):
    term_docId = []
    titleTokens = []
    captionTokens = []
    for i, doc in enumerate(medDocs):
        titleTokens += preprocessContent(doc['articleTitle'] )
        captionTokens += preprocessContent(doc['caption'])
        
        #term_docId += [(token,(i, 't')) for token in titleTokens]
        term_docId += [(token,(i, 'c')) for token in captionTokens]
#         for token in captionTokens:
#             term_docId[token].add((i, 'c'))
        
    return term_docId

termsPostings = getTerms(medDocs)
print(len(termsPostings))
termsPostings
# Out:
# 1568891
# [('adrenal', (0, 'c')),
#  ('radiation', (0, 'c')),
#  ('planning', (0, 'c')),
#  ('depicted', (0, 'c')),
#  ('computed', (0, 'c')),
#  ('tomography', (0, 'c')),
#  ('scan', (0, 'c')),
#  ('the', (0, 'c')),
#  ('abdomen', (0, 'c')),
#  ('planned', (0, 'c')),
#  ('target', (0, 'c')),
#  ('volume', (0, 'c')),
#  ('for', (0, 'c')),
#  ('adrenal', (0, 'c')),
#  ('sbrt', (0, 'c')),
#  ('included', (0, 'c')),
#  ('safety', (0, 'c')),
#  ('margin', (0, 'c')),
#  ('around', (0, 'c')),
#  ('the', (0, 'c')),
#  ('radiologic', (0, 'c')),
#  ('abnormality', (0, 'c')),
#  ('organs', (0, 'c')),
#  ('risk', (0, 'c')),
#  ('for', (0, 'c')),
#  ('damage', (0, 'c')),
#  ('from', (0, 'c')),
#  ('radiation', (0, 'c')),
#  ('treatment', (0, 'c')),
#  ('included', (0, 'c')),
#  ('bilateral', (0, 'c')),
#  ('kidneys', (0, 'c')),
#  ('spinal', (0, 'c')),
#  ('cord', (0, 'c')),
#  ('stomach', (0, 'c')),
#  ('bowel', (0, 'c')),
#  ('and', (0, 'c')),
#  ('liver', (0, 'c')),
#  ('image', (0, 'c')),
#  ('shows', (0, 'c')),
#  ('orientation', (0, 'c')),
#  ('stereotactic', (0, 'c')),
#  ('radiotherapy', (0, 'c')),
#  ('beam', (0, 'c')),
#  ('arcs', (0, 'c')),
#  ('one', (0, 'c')),
#  ('clockwise', (0, 'c')),
#  ('and', (0, 'c')),
#  ('one', (0, 'c')),
#  ('counterclockwise', (0, 'c')),
#  ('partial-arc', (0, 'c')),
#  ('arrangement', (0, 'c')),
#  ('was', (0, 'c')),
#  ('utilized', (0, 'c')),
#  ('treat', (0, 'c')),
#  ('each', (0, 'c')),
#  ('target', (0, 'c')),
#  ('the', (0, 'c')),
#  ('adrenal', (0, 'c')),
#  ('beds', (0, 'c')),
#  ('were', (0, 'c')),
#  ('treated', (0, 'c')),
#  ('cgy', (0, 'c')),
#  ('fractions', (0, 'c')),
#  ('dose', (0, 'c')),
#  ('color-wash', (0, 'c')),
#  ('approximately', (0, 'c')),
#  ('level', (0, 'c')),
#  ('shows', (0, 'c')),
#  ('rapid', (0, 'c')),
#  ('dose', (0, 'c')),
#  ('fall-off', (0, 'c')),
#  ('and', (0, 'c')),
#  ('excellent', (0, 'c')),
#  ('sparing', (0, 'c')),
#  ('oars', (0, 'c')),
#  ('sbrt', (0, 'c')),
#  ('stereotactic', (0, 'c')),
#  ('body', (0, 'c')),
#  ('radiotherapy', (0, 'c')),
#  ('adrenal', (1, 'c')),
#  ('radiation', (1, 'c')),
#  ('planning', (1, 'c')),
#  ('depicted', (1, 'c')),
#  ('computed', (1, 'c')),
#  ('tomography', (1, 'c')),
#  ('scan', (1, 'c')),
#  ('the', (1, 'c')),
#  ('abdomen', (1, 'c')),
#  ('planned', (1, 'c')),
#  ('target', (1, 'c')),
#  ('volume', (1, 'c')),
#  ('for', (1, 'c')),
#  ('adrenal', (1, 'c')),
#  ('sbrt', (1, 'c')),
#  ('included', (1, 'c')),
#  ('safety', (1, 'c')),
#  ('margin', (1, 'c')),
#  ('around', (1, 'c')),
#  ('the', (1, 'c')),
#  ('radiologic', (1, 'c')),
#  ('abnormality', (1, 'c')),
#  ('organs', (1, 'c')),
#  ('risk', (1, 'c')),
#  ('for', (1, 'c')),
#  ('damage', (1, 'c')),
#  ('from', (1, 'c')),
#  ('radiation', (1, 'c')),
#  ('treatment', (1, 'c')),
#  ('included', (1, 'c')),
#  ('bilateral', (1, 'c')),
#  ('kidneys', (1, 'c')),
#  ('spinal', (1, 'c')),
#  ('cord', (1, 'c')),
#  ('stomach', (1, 'c')),
#  ('bowel', (1, 'c')),
#  ('and', (1, 'c')),
#  ('liver', (1, 'c')),
#  ('image', (1, 'c')),
#  ('shows', (1, 'c')),
#  ('orientation', (1, 'c')),
#  ('stereotactic', (1, 'c')),
#  ('radiotherapy', (1, 'c')),
#  ('beam', (1, 'c')),
#  ('arcs', (1, 'c')),
#  ('one', (1, 'c')),
#  ('clockwise', (1, 'c')),
#  ('and', (1, 'c')),
#  ('one', (1, 'c')),
#  ('counterclockwise', (1, 'c')),
#  ('partial-arc', (1, 'c')),
#  ('arrangement', (1, 'c')),
#  ('was', (1, 'c')),
#  ('utilized', (1, 'c')),
#  ('treat', (1, 'c')),
#  ('each', (1, 'c')),
#  ('target', (1, 'c')),
#  ('the', (1, 'c')),
#  ('adrenal', (1, 'c')),
#  ('beds', (1, 'c')),
#  ('were', (1, 'c')),
#  ('treated', (1, 'c')),
#  ('cgy', (1, 'c')),
#  ('fractions', (1, 'c')),
#  ('dose', (1, 'c')),
#  ('color-wash', (1, 'c')),
#  ('approximately', (1, 'c')),
#  ('level', (1, 'c')),
#  ('shows', (1, 'c')),
#  ('rapid', (1, 'c')),
#  ('dose', (1, 'c')),
#  ('fall-off', (1, 'c')),
#  ('and', (1, 'c')),
#  ('excellent', (1, 'c')),
#  ('sparing', (1, 'c')),
#  ('oars', (1, 'c')),
#  ('sbrt', (1, 'c')),
#  ('stereotactic', (1, 'c')),
#  ('body', (1, 'c')),
#  ('radiotherapy', (1, 'c')),
#  ('graph', (1, 'c')),
#  ('shows', (1, 'c')),
#  ('changes', (1, 'c')),
#  ('serum', (1, 'c')),
#  ('cortisol', (1, 'c')),
#  ('and', (1, 'c')),
#  ('plasma', (1, 'c')),
#  ('acth', (1, 'c')),
#  ('levels', (1, 'c')),
#  ('over', (1, 'c')),
#  ('time', (1, 'c')),
#  ('treatment', (1, 'c')),
#  ('chronology', (1, 'c')),
#  ('included', (1, 'c')),
#  ('for', (1, 'c')),
#  ('reference', (1, 'c')),
#  ('acth', (1, 'c')),
#  ('adrenocortico-tropic', (1, 'c')),
#  ('hormone', (1, 'c')),
#  ('sbrt', (1, 'c')),
#  ('stereotactic', (1, 'c')),
#  ('body', (1, 'c')),
#  ('radiotherapy', (1, 'c')),
#  ('adrenal', (2, 'c')),
#  ('radiation', (2, 'c')),
#  ('planning', (2, 'c')),
#  ('depicted', (2, 'c')),
#  ('computed', (2, 'c')),
#  ('tomography', (2, 'c')),
#  ('scan', (2, 'c')),
#  ('the', (2, 'c')),
#  ('abdomen', (2, 'c')),
#  ('planned', (2, 'c')),
#  ('target', (2, 'c')),
#  ('volume', (2, 'c')),
#  ('for', (2, 'c')),
#  ('adrenal', (2, 'c')),
#  ('sbrt', (2, 'c')),
#  ('included', (2, 'c')),
#  ('safety', (2, 'c')),
#  ('margin', (2, 'c')),
#  ('around', (2, 'c')),
#  ('the', (2, 'c')),
#  ('radiologic', (2, 'c')),
#  ('abnormality', (2, 'c')),
#  ('organs', (2, 'c')),
#  ('risk', (2, 'c')),
#  ('for', (2, 'c')),
#  ('damage', (2, 'c')),
#  ('from', (2, 'c')),
#  ('radiation', (2, 'c')),
#  ('treatment', (2, 'c')),
#  ('included', (2, 'c')),
#  ('bilateral', (2, 'c')),
#  ('kidneys', (2, 'c')),
#  ('spinal', (2, 'c')),
#  ('cord', (2, 'c')),
#  ('stomach', (2, 'c')),
#  ('bowel', (2, 'c')),
#  ('and', (2, 'c')),
#  ('liver', (2, 'c')),
#  ('image', (2, 'c')),
#  ('shows', (2, 'c')),
#  ('orientation', (2, 'c')),
#  ('stereotactic', (2, 'c')),
#  ('radiotherapy', (2, 'c')),
#  ('beam', (2, 'c')),
#  ('arcs', (2, 'c')),
#  ('one', (2, 'c')),
#  ('clockwise', (2, 'c')),
#  ('and', (2, 'c')),
#  ('one', (2, 'c')),
#  ('counterclockwise', (2, 'c')),
#  ('partial-arc', (2, 'c')),
#  ('arrangement', (2, 'c')),
#  ('was', (2, 'c')),
#  ('utilized', (2, 'c')),
#  ('treat', (2, 'c')),
#  ('each', (2, 'c')),
#  ('target', (2, 'c')),
#  ('the', (2, 'c')),
#  ('adrenal', (2, 'c')),
#  ('beds', (2, 'c')),
#  ('were', (2, 'c')),
#  ('treated', (2, 'c')),
#  ('cgy', (2, 'c')),
#  ('fractions', (2, 'c')),
#  ('dose', (2, 'c')),
#  ('color-wash', (2, 'c')),
#  ('approximately', (2, 'c')),
#  ('level', (2, 'c')),
#  ('shows', (2, 'c')),
#  ('rapid', (2, 'c')),
#  ('dose', (2, 'c')),
#  ('fall-off', (2, 'c')),
#  ('and', (2, 'c')),
#  ('excellent', (2, 'c')),
#  ('sparing', (2, 'c')),
#  ('oars', (2, 'c')),
#  ('sbrt', (2, 'c')),
#  ('stereotactic', (2, 'c')),
#  ('body', (2, 'c')),
#  ('radiotherapy', (2, 'c')),
#  ('graph', (2, 'c')),
#  ('shows', (2, 'c')),
#  ('changes', (2, 'c')),
#  ('serum', (2, 'c')),
#  ('cortisol', (2, 'c')),
#  ('and', (2, 'c')),
#  ('plasma', (2, 'c')),
#  ('acth', (2, 'c')),
#  ('levels', (2, 'c')),
#  ('over', (2, 'c')),
#  ('time', (2, 'c')),
#  ('treatment', (2, 'c')),
#  ('chronology', (2, 'c')),
#  ('included', (2, 'c')),
#  ('for', (2, 'c')),
#  ('reference', (2, 'c')),
#  ('acth', (2, 'c')),
#  ('adrenocortico-tropic', (2, 'c')),
#  ('hormone', (2, 'c')),
#  ('sbrt', (2, 'c')),
#  ('stereotactic', (2, 'c')),
#  ('body', (2, 'c')),
#  ('radiotherapy', (2, 'c')),
#  ('migratory', (2, 'c')),
#  ('necrolytic', (2, 'c')),
#  ('erythema', (2, 'c')),
#  ('the', (2, 'c')),
#  ('face', (2, 'c')),
#  ('showing', (2, 'c')),
#  ('hyperpigmented', (2, 'c')),
#  ('and', (2, 'c')),
#  ('erythematous', (2, 'c')),
#  ('lesions', (2, 'c')),
#  ('adrenal', (3, 'c')),
#  ('radiation', (3, 'c')),
#  ('planning', (3, 'c')),
#  ('depicted', (3, 'c')),
#  ('computed', (3, 'c')),
#  ('tomography', (3, 'c')),
#  ('scan', (3, 'c')),
#  ('the', (3, 'c')),
#  ('abdomen', (3, 'c')),
#  ('planned', (3, 'c')),
#  ('target', (3, 'c')),
#  ('volume', (3, 'c')),
#  ('for', (3, 'c')),
#  ('adrenal', (3, 'c')),
#  ('sbrt', (3, 'c')),
#  ('included', (3, 'c')),
#  ('safety', (3, 'c')),
#  ('margin', (3, 'c')),
#  ('around', (3, 'c')),
#  ('the', (3, 'c')),
#  ('radiologic', (3, 'c')),
#  ('abnormality', (3, 'c')),
#  ('organs', (3, 'c')),
#  ('risk', (3, 'c')),
#  ('for', (3, 'c')),
#  ('damage', (3, 'c')),
#  ('from', (3, 'c')),
#  ('radiation', (3, 'c')),
#  ('treatment', (3, 'c')),
#  ('included', (3, 'c')),
#  ('bilateral', (3, 'c')),
#  ('kidneys', (3, 'c')),
#  ('spinal', (3, 'c')),
#  ('cord', (3, 'c')),
#  ('stomach', (3, 'c')),
#  ('bowel', (3, 'c')),
#  ('and', (3, 'c')),
#  ('liver', (3, 'c')),
#  ('image', (3, 'c')),
#  ('shows', (3, 'c')),
#  ('orientation', (3, 'c')),
#  ('stereotactic', (3, 'c')),
#  ('radiotherapy', (3, 'c')),
#  ('beam', (3, 'c')),
#  ('arcs', (3, 'c')),
#  ('one', (3, 'c')),
#  ('clockwise', (3, 'c')),
#  ('and', (3, 'c')),
#  ('one', (3, 'c')),
#  ('counterclockwise', (3, 'c')),
#  ('partial-arc', (3, 'c')),
#  ('arrangement', (3, 'c')),
#  ('was', (3, 'c')),
#  ('utilized', (3, 'c')),
#  ('treat', (3, 'c')),
#  ('each', (3, 'c')),
#  ('target', (3, 'c')),
#  ('the', (3, 'c')),
#  ('adrenal', (3, 'c')),
#  ('beds', (3, 'c')),
#  ('were', (3, 'c')),
#  ('treated', (3, 'c')),
#  ('cgy', (3, 'c')),
#  ('fractions', (3, 'c')),
#  ('dose', (3, 'c')),
#  ('color-wash', (3, 'c')),
#  ('approximately', (3, 'c')),
#  ('level', (3, 'c')),
#  ('shows', (3, 'c')),
#  ('rapid', (3, 'c')),
#  ('dose', (3, 'c')),
#  ('fall-off', (3, 'c')),
#  ('and', (3, 'c')),
#  ('excellent', (3, 'c')),
#  ('sparing', (3, 'c')),
#  ('oars', (3, 'c')),
#  ('sbrt', (3, 'c')),
#  ('stereotactic', (3, 'c')),
#  ('body', (3, 'c')),
#  ('radiotherapy', (3, 'c')),
#  ('graph', (3, 'c')),
#  ('shows', (3, 'c')),
#  ('changes', (3, 'c')),
#  ('serum', (3, 'c')),
#  ('cortisol', (3, 'c')),
#  ('and', (3, 'c')),
#  ('plasma', (3, 'c')),
#  ('acth', (3, 'c')),
#  ('levels', (3, 'c')),
#  ('over', (3, 'c')),
#  ('time', (3, 'c')),
#  ('treatment', (3, 'c')),
#  ('chronology', (3, 'c')),
#  ('included', (3, 'c')),
#  ('for', (3, 'c')),
#  ('reference', (3, 'c')),
#  ('acth', (3, 'c')),
#  ('adrenocortico-tropic', (3, 'c')),
#  ('hormone', (3, 'c')),
#  ('sbrt', (3, 'c')),
#  ('stereotactic', (3, 'c')),
#  ('body', (3, 'c')),
#  ('radiotherapy', (3, 'c')),
#  ('migratory', (3, 'c')),
#  ('necrolytic', (3, 'c')),
#  ('erythema', (3, 'c')),
#  ('the', (3, 'c')),
#  ('face', (3, 'c')),
#  ('showing', (3, 'c')),
#  ('hyperpigmented', (3, 'c')),
#  ('and', (3, 'c')),
#  ('erythematous', (3, 'c')),
#  ('lesions', (3, 'c')),
#  ('cheilitis', (3, 'c')),
#  ('and', (3, 'c')),
#  ('glossitis', (3, 'c')),
#  ('adrenal', (4, 'c')),
#  ('radiation', (4, 'c')),
#  ('planning', (4, 'c')),
#  ('depicted', (4, 'c')),
#  ('computed', (4, 'c')),
#  ('tomography', (4, 'c')),
#  ('scan', (4, 'c')),
#  ('the', (4, 'c')),
#  ('abdomen', (4, 'c')),
#  ('planned', (4, 'c')),
#  ('target', (4, 'c')),
#  ('volume', (4, 'c')),
#  ('for', (4, 'c')),
#  ('adrenal', (4, 'c')),
#  ('sbrt', (4, 'c')),
#  ('included', (4, 'c')),
#  ('safety', (4, 'c')),
#  ('margin', (4, 'c')),
#  ('around', (4, 'c')),
#  ('the', (4, 'c')),
#  ('radiologic', (4, 'c')),
#  ('abnormality', (4, 'c')),
#  ('organs', (4, 'c')),
#  ('risk', (4, 'c')),
#  ('for', (4, 'c')),
#  ('damage', (4, 'c')),
#  ('from', (4, 'c')),
#  ('radiation', (4, 'c')),
#  ('treatment', (4, 'c')),
#  ('included', (4, 'c')),
#  ('bilateral', (4, 'c')),
#  ('kidneys', (4, 'c')),
#  ('spinal', (4, 'c')),
#  ('cord', (4, 'c')),
#  ('stomach', (4, 'c')),
#  ('bowel', (4, 'c')),
#  ('and', (4, 'c')),
#  ('liver', (4, 'c')),
#  ('image', (4, 'c')),
#  ('shows', (4, 'c')),
#  ('orientation', (4, 'c')),
#  ('stereotactic', (4, 'c')),
#  ('radiotherapy', (4, 'c')),
#  ('beam', (4, 'c')),
#  ('arcs', (4, 'c')),
#  ('one', (4, 'c')),
#  ('clockwise', (4, 'c')),
#  ('and', (4, 'c')),
#  ('one', (4, 'c')),
#  ('counterclockwise', (4, 'c')),
#  ('partial-arc', (4, 'c')),
#  ('arrangement', (4, 'c')),
#  ('was', (4, 'c')),
#  ('utilized', (4, 'c')),
#  ('treat', (4, 'c')),
#  ('each', (4, 'c')),
#  ('target', (4, 'c')),
#  ('the', (4, 'c')),
#  ('adrenal', (4, 'c')),
#  ('beds', (4, 'c')),
#  ('were', (4, 'c')),
#  ('treated', (4, 'c')),
#  ('cgy', (4, 'c')),
#  ('fractions', (4, 'c')),
#  ('dose', (4, 'c')),
#  ('color-wash', (4, 'c')),
#  ('approximately', (4, 'c')),
#  ('level', (4, 'c')),
#  ('shows', (4, 'c')),
#  ('rapid', (4, 'c')),
#  ('dose', (4, 'c')),
#  ('fall-off', (4, 'c')),
#  ('and', (4, 'c')),
#  ('excellent', (4, 'c')),
#  ('sparing', (4, 'c')),
#  ('oars', (4, 'c')),
#  ('sbrt', (4, 'c')),
#  ('stereotactic', (4, 'c')),
#  ('body', (4, 'c')),
#  ('radiotherapy', (4, 'c')),
#  ('graph', (4, 'c')),
#  ('shows', (4, 'c')),
#  ('changes', (4, 'c')),
#  ('serum', (4, 'c')),
#  ('cortisol', (4, 'c')),
#  ('and', (4, 'c')),
#  ('plasma', (4, 'c')),
#  ('acth', (4, 'c')),
#  ('levels', (4, 'c')),
#  ('over', (4, 'c')),
#  ('time', (4, 'c')),
#  ('treatment', (4, 'c')),
#  ('chronology', (4, 'c')),
#  ('included', (4, 'c')),
#  ('for', (4, 'c')),
#  ('reference', (4, 'c')),
#  ('acth', (4, 'c')),
#  ('adrenocortico-tropic', (4, 'c')),
#  ('hormone', (4, 'c')),
#  ('sbrt', (4, 'c')),
#  ('stereotactic', (4, 'c')),
#  ('body', (4, 'c')),
#  ('radiotherapy', (4, 'c')),
#  ('migratory', (4, 'c')),
#  ('necrolytic', (4, 'c')),
#  ('erythema', (4, 'c')),
#  ('the', (4, 'c')),
#  ('face', (4, 'c')),
#  ('showing', (4, 'c')),
#  ('hyperpigmented', (4, 'c')),
#  ('and', (4, 'c')),
#  ('erythematous', (4, 'c')),
#  ('lesions', (4, 'c')),
#  ('cheilitis', (4, 'c')),
#  ('and', (4, 'c')),
#  ('glossitis', (4, 'c')),
#  ('axial', (4, 'c')),
#  ('computed', (4, 'c')),
#  ('tomography', (4, 'c')),
#  ('the', (4, 'c')),
#  ('abdomen', (4, 'c')),
#  ('showing', (4, 'c')),
#  ('masses', (4, 'c')),
#  ('the', (4, 'c')),
#  ('pancreatic', (4, 'c')),
#  ('tail', (4, 'c')),
#  ('and', (4, 'c')),
#  ('right', (4, 'c')),
#  ('hepatic', (4, 'c')),
#  ('lobe', (4, 'c')),
#  ('adrenal', (5, 'c')),
#  ('radiation', (5, 'c')),
#  ('planning', (5, 'c')),
#  ('depicted', (5, 'c')),
#  ('computed', (5, 'c')),
#  ('tomography', (5, 'c')),
#  ('scan', (5, 'c')),
#  ('the', (5, 'c')),
#  ('abdomen', (5, 'c')),
#  ('planned', (5, 'c')),
#  ('target', (5, 'c')),
#  ('volume', (5, 'c')),
#  ('for', (5, 'c')),
#  ('adrenal', (5, 'c')),
#  ('sbrt', (5, 'c')),
#  ('included', (5, 'c')),
#  ('safety', (5, 'c')),
#  ('margin', (5, 'c')),
#  ('around', (5, 'c')),
#  ('the', (5, 'c')),
#  ('radiologic', (5, 'c')),
#  ('abnormality', (5, 'c')),
#  ('organs', (5, 'c')),
#  ('risk', (5, 'c')),
#  ('for', (5, 'c')),
#  ('damage', (5, 'c')),
#  ('from', (5, 'c')),
#  ('radiation', (5, 'c')),
#  ('treatment', (5, 'c')),
#  ('included', (5, 'c')),
#  ('bilateral', (5, 'c')),
#  ('kidneys', (5, 'c')),
#  ('spinal', (5, 'c')),
#  ('cord', (5, 'c')),
#  ('stomach', (5, 'c')),
#  ('bowel', (5, 'c')),
#  ('and', (5, 'c')),
#  ('liver', (5, 'c')),
#  ('image', (5, 'c')),
#  ('shows', (5, 'c')),
#  ('orientation', (5, 'c')),
#  ('stereotactic', (5, 'c')),
#  ('radiotherapy', (5, 'c')),
#  ('beam', (5, 'c')),
#  ('arcs', (5, 'c')),
#  ('one', (5, 'c')),
#  ('clockwise', (5, 'c')),
#  ('and', (5, 'c')),
#  ('one', (5, 'c')),
#  ('counterclockwise', (5, 'c')),
#  ('partial-arc', (5, 'c')),
#  ('arrangement', (5, 'c')),
#  ('was', (5, 'c')),
#  ('utilized', (5, 'c')),
#  ('treat', (5, 'c')),
#  ('each', (5, 'c')),
#  ('target', (5, 'c')),
#  ('the', (5, 'c')),
#  ('adrenal', (5, 'c')),
#  ('beds', (5, 'c')),
#  ('were', (5, 'c')),
#  ('treated', (5, 'c')),
#  ('cgy', (5, 'c')),
#  ('fractions', (5, 'c')),
#  ('dose', (5, 'c')),
#  ('color-wash', (5, 'c')),
#  ('approximately', (5, 'c')),
#  ('level', (5, 'c')),
#  ('shows', (5, 'c')),
#  ('rapid', (5, 'c')),
#  ('dose', (5, 'c')),
#  ('fall-off', (5, 'c')),
#  ('and', (5, 'c')),
#  ('excellent', (5, 'c')),
#  ('sparing', (5, 'c')),
#  ('oars', (5, 'c')),
#  ('sbrt', (5, 'c')),
#  ('stereotactic', (5, 'c')),
#  ('body', (5, 'c')),
#  ('radiotherapy', (5, 'c')),
#  ('graph', (5, 'c')),
#  ('shows', (5, 'c')),
#  ('changes', (5, 'c')),
#  ('serum', (5, 'c')),
#  ('cortisol', (5, 'c')),
#  ('and', (5, 'c')),
#  ('plasma', (5, 'c')),
#  ('acth', (5, 'c')),
#  ('levels', (5, 'c')),
#  ('over', (5, 'c')),
#  ('time', (5, 'c')),
#  ('treatment', (5, 'c')),
#  ('chronology', (5, 'c')),
#  ('included', (5, 'c')),
#  ('for', (5, 'c')),
#  ('reference', (5, 'c')),
#  ('acth', (5, 'c')),
#  ('adrenocortico-tropic', (5, 'c')),
#  ('hormone', (5, 'c')),
#  ('sbrt', (5, 'c')),
#  ('stereotactic', (5, 'c')),
#  ('body', (5, 'c')),
#  ('radiotherapy', (5, 'c')),
#  ('migratory', (5, 'c')),
#  ('necrolytic', (5, 'c')),
#  ('erythema', (5, 'c')),
#  ('the', (5, 'c')),
#  ('face', (5, 'c')),
#  ('showing', (5, 'c')),
#  ('hyperpigmented', (5, 'c')),
#  ('and', (5, 'c')),
#  ('erythematous', (5, 'c')),
#  ('lesions', (5, 'c')),
#  ('cheilitis', (5, 'c')),
#  ('and', (5, 'c')),
#  ('glossitis', (5, 'c')),
#  ('axial', (5, 'c')),
#  ('computed', (5, 'c')),
#  ('tomography', (5, 'c')),
#  ('the', (5, 'c')),
#  ('abdomen', (5, 'c')),
#  ('showing', (5, 'c')),
#  ('masses', (5, 'c')),
#  ('the', (5, 'c')),
#  ('pancreatic', (5, 'c')),
#  ('tail', (5, 'c')),
#  ('and', (5, 'c')),
#  ('right', (5, 'c')),
#  ('hepatic', (5, 'c')),
#  ('lobe', (5, 'c')),
#  ('histology', (5, 'c')),
#  ('showing', (5, 'c')),
#  ('nodular', (5, 'c')),
#  ('and', (5, 'c')),
#  ('trabecular', (5, 'c')),
#  ('structures', (5, 'c')),
#  ('formed', (5, 'c')),
#  ('cells', (5, 'c')),
#  ('with', (5, 'c')),
#  ('broad', (5, 'c')),
#  ('granular', (5, 'c')),
#  ('eosinophilic', (5, 'c')),
#  ('cytoplasm', (5, 'c')),
#  ('and', (5, 'c')),
#  ('homogeneous', (5, 'c')),
#  ('nuclei', (5, 'c')),
#  ('slight', (5, 'c')),
#  ('pleomorphism', (5, 'c')),
#  ('and', (5, 'c')),
#  ('some', (5, 'c')),
#  ('visible', (5, 'c')),
#  ('nucleoli', (5, 'c')),
#  ('are', (5, 'c')),
#  ('also', (5, 'c')),
#  ('observed', (5, 'c')),
#  ('but', (5, 'c')),
#  ('important', (5, 'c')),
#  ('mitotic', (5, 'c')),
#  ('activity', (5, 'c')),
#  ('observed', (5, 'c')),
#  ('adrenal', (6, 'c')),
#  ('radiation', (6, 'c')),
#  ('planning', (6, 'c')),
#  ('depicted', (6, 'c')),
#  ('computed', (6, 'c')),
#  ('tomography', (6, 'c')),
#  ('scan', (6, 'c')),
#  ('the', (6, 'c')),
#  ('abdomen', (6, 'c')),
#  ('planned', (6, 'c')),
#  ('target', (6, 'c')),
#  ('volume', (6, 'c')),
#  ('for', (6, 'c')),
#  ('adrenal', (6, 'c')),
#  ('sbrt', (6, 'c')),
#  ('included', (6, 'c')),
#  ('safety', (6, 'c')),
#  ('margin', (6, 'c')),
#  ('around', (6, 'c')),
#  ('the', (6, 'c')),
#  ('radiologic', (6, 'c')),
#  ('abnormality', (6, 'c')),
#  ('organs', (6, 'c')),
#  ('risk', (6, 'c')),
#  ('for', (6, 'c')),
#  ('damage', (6, 'c')),
#  ('from', (6, 'c')),
#  ('radiation', (6, 'c')),
#  ('treatment', (6, 'c')),
#  ('included', (6, 'c')),
#  ('bilateral', (6, 'c')),
#  ('kidneys', (6, 'c')),
#  ('spinal', (6, 'c')),
#  ('cord', (6, 'c')),
#  ('stomach', (6, 'c')),
#  ('bowel', (6, 'c')),
#  ('and', (6, 'c')),
#  ('liver', (6, 'c')),
#  ('image', (6, 'c')),
#  ('shows', (6, 'c')),
#  ('orientation', (6, 'c')),
#  ('stereotactic', (6, 'c')),
#  ('radiotherapy', (6, 'c')),
#  ('beam', (6, 'c')),
#  ('arcs', (6, 'c')),
#  ('one', (6, 'c')),
#  ('clockwise', (6, 'c')),
#  ('and', (6, 'c')),
#  ('one', (6, 'c')),
#  ('counterclockwise', (6, 'c')),
#  ('partial-arc', (6, 'c')),
#  ('arrangement', (6, 'c')),
#  ('was', (6, 'c')),
#  ('utilized', (6, 'c')),
#  ('treat', (6, 'c')),
#  ('each', (6, 'c')),
#  ('target', (6, 'c')),
#  ('the', (6, 'c')),
#  ('adrenal', (6, 'c')),
#  ('beds', (6, 'c')),
#  ('were', (6, 'c')),
#  ('treated', (6, 'c')),
#  ('cgy', (6, 'c')),
#  ('fractions', (6, 'c')),
#  ('dose', (6, 'c')),
#  ('color-wash', (6, 'c')),
#  ('approximately', (6, 'c')),
#  ('level', (6, 'c')),
#  ('shows', (6, 'c')),
#  ('rapid', (6, 'c')),
#  ('dose', (6, 'c')),
#  ('fall-off', (6, 'c')),
#  ('and', (6, 'c')),
#  ('excellent', (6, 'c')),
#  ('sparing', (6, 'c')),
#  ('oars', (6, 'c')),
#  ('sbrt', (6, 'c')),
#  ('stereotactic', (6, 'c')),
#  ('body', (6, 'c')),
#  ('radiotherapy', (6, 'c')),
#  ('graph', (6, 'c')),
#  ('shows', (6, 'c')),
#  ('changes', (6, 'c')),
#  ('serum', (6, 'c')),
#  ('cortisol', (6, 'c')),
#  ('and', (6, 'c')),
#  ('plasma', (6, 'c')),
#  ('acth', (6, 'c')),
#  ('levels', (6, 'c')),
#  ('over', (6, 'c')),
#  ('time', (6, 'c')),
#  ('treatment', (6, 'c')),
#  ('chronology', (6, 'c')),
#  ('included', (6, 'c')),
#  ('for', (6, 'c')),
#  ('reference', (6, 'c')),
#  ('acth', (6, 'c')),
#  ('adrenocortico-tropic', (6, 'c')),
#  ('hormone', (6, 'c')),
#  ('sbrt', (6, 'c')),
#  ('stereotactic', (6, 'c')),
#  ('body', (6, 'c')),
#  ('radiotherapy', (6, 'c')),
#  ('migratory', (6, 'c')),
#  ('necrolytic', (6, 'c')),
#  ('erythema', (6, 'c')),
#  ('the', (6, 'c')),
#  ('face', (6, 'c')),
#  ('showing', (6, 'c')),
#  ('hyperpigmented', (6, 'c')),
#  ('and', (6, 'c')),
#  ('erythematous', (6, 'c')),
#  ('lesions', (6, 'c')),
#  ('cheilitis', (6, 'c')),
#  ('and', (6, 'c')),
#  ('glossitis', (6, 'c')),
#  ('axial', (6, 'c')),
#  ('computed', (6, 'c')),
#  ('tomography', (6, 'c')),
#  ('the', (6, 'c')),
#  ('abdomen', (6, 'c')),
#  ('showing', (6, 'c')),
#  ('masses', (6, 'c')),
#  ('the', (6, 'c')),
#  ('pancreatic', (6, 'c')),
#  ('tail', (6, 'c')),
#  ('and', (6, 'c')),
#  ('right', (6, 'c')),
#  ('hepatic', (6, 'c')),
#  ('lobe', (6, 'c')),
#  ('histology', (6, 'c')),
#  ('showing', (6, 'c')),
#  ('nodular', (6, 'c')),
#  ('and', (6, 'c')),
#  ('trabecular', (6, 'c')),
#  ('structures', (6, 'c')),
#  ('formed', (6, 'c')),
#  ('cells', (6, 'c')),
#  ('with', (6, 'c')),
#  ('broad', (6, 'c')),
#  ('granular', (6, 'c')),
#  ('eosinophilic', (6, 'c')),
#  ('cytoplasm', (6, 'c')),
#  ('and', (6, 'c')),
#  ('homogeneous', (6, 'c')),
#  ('nuclei', (6, 'c')),
#  ('slight', (6, 'c')),
#  ('pleomorphism', (6, 'c')),
#  ('and', (6, 'c')),
#  ('some', (6, 'c')),
#  ('visible', (6, 'c')),
#  ('nucleoli', (6, 'c')),
#  ('are', (6, 'c')),
#  ('also', (6, 'c')),
#  ('observed', (6, 'c')),
#  ('but', (6, 'c')),
#  ('important', (6, 'c')),
#  ('mitotic', (6, 'c')),
#  ('activity', (6, 'c')),
#  ('observed', (6, 'c')),
#  ('clinical', (6, 'c')),
#  ('features', (6, 'c')),
#  ('pembrolizumab-induced', (6, 'c')),
#  ('lipodystrophy', (6, 'c')),
#  ('clinical', (6, 'c')),
#  ('photographs', (6, 'c')),
#  ('that', (6, 'c')),
#  ('demonstrate', (6, 'c')),
#  ('the', (6, 'c')),
#  ('change', (6, 'c')),
#  ('fat', (6, 'c')),
#  ('distribution', (6, 'c')),
#  ('before', (6, 'c')),
#  ('and', (6, 'c')),
#  ('after', (6, 'c')),
#  ('treatment', (6, 'c')),
#  ('with', (6, 'c')),
#  ('pembrolizumab', (6, 'c')),
#  ('before', (6, 'c')),
#  ('treatment', (6, 'c')),
#  ('after', (6, 'c')),
#  ('initiation', (6, 'c')),
#  ('immunotherapy', (6, 'c')),
#  ('there', (6, 'c')),
#  ('central', (6, 'c')),
#  ('obesity', (6, 'c')),
#  ('and', (6, 'c')),
#  ('decreased', (6, 'c')),
#  ('adipose', (6, 'c')),
#  ('tissue', (6, 'c')),
#  ('the', (6, 'c')),
#  ('extremities', (6, 'c')),
#  ('adrenal', (7, 'c')),
#  ('radiation', (7, 'c')),
#  ('planning', (7, 'c')),
#  ('depicted', (7, 'c')),
#  ('computed', (7, 'c')),
#  ('tomography', (7, 'c')),
#  ('scan', (7, 'c')),
#  ('the', (7, 'c')),
#  ('abdomen', (7, 'c')),
#  ('planned', (7, 'c')),
#  ('target', (7, 'c')),
#  ('volume', (7, 'c')),
#  ('for', (7, 'c')),
#  ('adrenal', (7, 'c')),
#  ('sbrt', (7, 'c')),
#  ('included', (7, 'c')),
#  ('safety', (7, 'c')),
#  ('margin', (7, 'c')),
#  ('around', (7, 'c')),
#  ('the', (7, 'c')),
#  ('radiologic', (7, 'c')),
#  ('abnormality', (7, 'c')),
#  ('organs', (7, 'c')),
#  ('risk', (7, 'c')),
#  ('for', (7, 'c')),
#  ('damage', (7, 'c')),
#  ('from', (7, 'c')),
#  ('radiation', (7, 'c')),
#  ('treatment', (7, 'c')),
#  ('included', (7, 'c')),
#  ('bilateral', (7, 'c')),
#  ('kidneys', (7, 'c')),
#  ('spinal', (7, 'c')),
#  ('cord', (7, 'c')),
#  ('stomach', (7, 'c')),
#  ('bowel', (7, 'c')),
#  ('and', (7, 'c')),
#  ('liver', (7, 'c')),
#  ('image', (7, 'c')),
#  ('shows', (7, 'c')),
#  ('orientation', (7, 'c')),
#  ('stereotactic', (7, 'c')),
#  ('radiotherapy', (7, 'c')),
#  ('beam', (7, 'c')),
#  ('arcs', (7, 'c')),
#  ('one', (7, 'c')),
#  ('clockwise', (7, 'c')),
#  ('and', (7, 'c')),
#  ('one', (7, 'c')),
#  ('counterclockwise', (7, 'c')),
#  ('partial-arc', (7, 'c')),
#  ('arrangement', (7, 'c')),
#  ('was', (7, 'c')),
#  ('utilized', (7, 'c')),
#  ('treat', (7, 'c')),
#  ('each', (7, 'c')),
#  ('target', (7, 'c')),
#  ('the', (7, 'c')),
#  ('adrenal', (7, 'c')),
#  ('beds', (7, 'c')),
#  ('were', (7, 'c')),
#  ('treated', (7, 'c')),
#  ('cgy', (7, 'c')),
#  ('fractions', (7, 'c')),
#  ('dose', (7, 'c')),
#  ('color-wash', (7, 'c')),
#  ('approximately', (7, 'c')),
#  ('level', (7, 'c')),
#  ('shows', (7, 'c')),
#  ('rapid', (7, 'c')),
#  ('dose', (7, 'c')),
#  ('fall-off', (7, 'c')),
#  ('and', (7, 'c')),
#  ('excellent', (7, 'c')),
#  ('sparing', (7, 'c')),
#  ('oars', (7, 'c')),
#  ('sbrt', (7, 'c')),
#  ('stereotactic', (7, 'c')),
#  ('body', (7, 'c')),
#  ('radiotherapy', (7, 'c')),
#  ('graph', (7, 'c')),
#  ('shows', (7, 'c')),
#  ('changes', (7, 'c')),
#  ('serum', (7, 'c')),
#  ('cortisol', (7, 'c')),
#  ('and', (7, 'c')),
#  ('plasma', (7, 'c')),
#  ('acth', (7, 'c')),
#  ('levels', (7, 'c')),
#  ('over', (7, 'c')),
#  ('time', (7, 'c')),
#  ('treatment', (7, 'c')),
#  ('chronology', (7, 'c')),
#  ('included', (7, 'c')),
#  ('for', (7, 'c')),
#  ('reference', (7, 'c')),
#  ('acth', (7, 'c')),
#  ('adrenocortico-tropic', (7, 'c')),
#  ('hormone', (7, 'c')),
#  ('sbrt', (7, 'c')),
#  ('stereotactic', (7, 'c')),
#  ('body', (7, 'c')),
#  ('radiotherapy', (7, 'c')),
#  ('migratory', (7, 'c')),
#  ('necrolytic', (7, 'c')),
#  ('erythema', (7, 'c')),
#  ...]

# %%
termsPostings[0]
# Out:
# ('adrenal', (0, 'c'))

# %%
#from operator import itemgetter
sortedTermsPostings = sorted(termsPostings,key=lambda x: x[0])
sortedTermsPostings
# Out:
# [('. .', (80, 'c')),
#  ('. .', (81, 'c')),
#  ('. .', (82, 'c')),
#  ('. .', (83, 'c')),
#  ('. .', (84, 'c')),
#  ('. .', (85, 'c')),
#  ('. .', (86, 'c')),
#  ('. .', (87, 'c')),
#  ('. .', (88, 'c')),
#  ('. .', (89, 'c')),
#  ('. .', (90, 'c')),
#  ('. .', (91, 'c')),
#  ('. .', (92, 'c')),
#  ('. .', (93, 'c')),
#  ('. .', (94, 'c')),
#  ('. .', (95, 'c')),
#  ('. .', (96, 'c')),
#  ('. .', (97, 'c')),
#  ('. .', (98, 'c')),
#  ('. .', (99, 'c')),
#  ('. .', (100, 'c')),
#  ('. .', (101, 'c')),
#  ('. .', (102, 'c')),
#  ('. .', (103, 'c')),
#  ('. .', (104, 'c')),
#  ('. .', (105, 'c')),
#  ('. .', (106, 'c')),
#  ('. .', (107, 'c')),
#  ('. .', (108, 'c')),
#  ('. .', (109, 'c')),
#  ('. .', (110, 'c')),
#  ('. .', (111, 'c')),
#  ('. .', (112, 'c')),
#  ('. .', (113, 'c')),
#  ('. .', (114, 'c')),
#  ('. .', (115, 'c')),
#  ('. .', (116, 'c')),
#  ('. .', (117, 'c')),
#  ('. .', (118, 'c')),
#  ('. .', (119, 'c')),
#  ('. .', (120, 'c')),
#  ('. .', (121, 'c')),
#  ('. .', (122, 'c')),
#  ('. .', (123, 'c')),
#  ('. .', (124, 'c')),
#  ('. .', (125, 'c')),
#  ('. .', (126, 'c')),
#  ('. .', (127, 'c')),
#  ('. .', (128, 'c')),
#  ('. .', (129, 'c')),
#  ('. .', (130, 'c')),
#  ('. .', (131, 'c')),
#  ('. .', (132, 'c')),
#  ('. .', (133, 'c')),
#  ('. .', (134, 'c')),
#  ('. .', (135, 'c')),
#  ('. .', (136, 'c')),
#  ('. .', (137, 'c')),
#  ('. .', (138, 'c')),
#  ('. .', (139, 'c')),
#  ('. .', (140, 'c')),
#  ('. .', (141, 'c')),
#  ('. .', (142, 'c')),
#  ('. .', (143, 'c')),
#  ('. .', (144, 'c')),
#  ('. .', (145, 'c')),
#  ('. .', (146, 'c')),
#  ('. .', (147, 'c')),
#  ('. .', (148, 'c')),
#  ('. .', (149, 'c')),
#  ('. .', (150, 'c')),
#  ('. .', (151, 'c')),
#  ('. .', (152, 'c')),
#  ('. .', (153, 'c')),
#  ('. .', (154, 'c')),
#  ('. .', (155, 'c')),
#  ('. .', (156, 'c')),
#  ('. .', (157, 'c')),
#  ('. .', (158, 'c')),
#  ('. .', (159, 'c')),
#  ('. .', (160, 'c')),
#  ('. .', (161, 'c')),
#  ('. .', (162, 'c')),
#  ('. .', (163, 'c')),
#  ('. .', (164, 'c')),
#  ('. .', (165, 'c')),
#  ('. .', (166, 'c')),
#  ('. .', (167, 'c')),
#  ('. .', (168, 'c')),
#  ('. .', (169, 'c')),
#  ('. .', (170, 'c')),
#  ('. .', (171, 'c')),
#  ('. .', (172, 'c')),
#  ('. .', (173, 'c')),
#  ('. .', (174, 'c')),
#  ('. .', (175, 'c')),
#  ('. .', (176, 'c')),
#  ('. .', (177, 'c')),
#  ('. .', (178, 'c')),
#  ('. .', (179, 'c')),
#  ('. .', (180, 'c')),
#  ('. .', (181, 'c')),
#  ('. .', (182, 'c')),
#  ('. .', (183, 'c')),
#  ('. .', (184, 'c')),
#  ('. .', (185, 'c')),
#  ('. .', (186, 'c')),
#  ('. .', (187, 'c')),
#  ('. .', (188, 'c')),
#  ('. .', (189, 'c')),
#  ('. .', (190, 'c')),
#  ('. .', (191, 'c')),
#  ('. .', (192, 'c')),
#  ('. .', (193, 'c')),
#  ('. .', (194, 'c')),
#  ('. .', (195, 'c')),
#  ('. .', (196, 'c')),
#  ('. .', (197, 'c')),
#  ('. .', (198, 'c')),
#  ('. .', (199, 'c')),
#  ('. .', (200, 'c')),
#  ('. .', (201, 'c')),
#  ('. .', (202, 'c')),
#  ('. .', (203, 'c')),
#  ('. .', (204, 'c')),
#  ('. .', (205, 'c')),
#  ('. .', (206, 'c')),
#  ('. .', (207, 'c')),
#  ('. .', (208, 'c')),
#  ('. .', (209, 'c')),
#  ('. .', (210, 'c')),
#  ('. .', (211, 'c')),
#  ('. .', (212, 'c')),
#  ('. .', (213, 'c')),
#  ('. .', (214, 'c')),
#  ('. .', (214, 'c')),
#  ('. .', (214, 'c')),
#  ('. .', (215, 'c')),
#  ('. .', (215, 'c')),
#  ('. .', (215, 'c')),
#  ('. .', (216, 'c')),
#  ('. .', (216, 'c')),
#  ('. .', (216, 'c')),
#  ('. .', (217, 'c')),
#  ('. .', (217, 'c')),
#  ('. .', (217, 'c')),
#  ('. .', (218, 'c')),
#  ('. .', (218, 'c')),
#  ('. .', (218, 'c')),
#  ('. .', (218, 'c')),
#  ('. .', (219, 'c')),
#  ('. .', (219, 'c')),
#  ('. .', (219, 'c')),
#  ('. .', (219, 'c')),
#  ('. .', (220, 'c')),
#  ('. .', (220, 'c')),
#  ('. .', (220, 'c')),
#  ('. .', (220, 'c')),
#  ('. .', (221, 'c')),
#  ('. .', (221, 'c')),
#  ('. .', (221, 'c')),
#  ('. .', (221, 'c')),
#  ('. .', (221, 'c')),
#  ('. .', (221, 'c')),
#  ('. .', (222, 'c')),
#  ('. .', (222, 'c')),
#  ('. .', (222, 'c')),
#  ('. .', (222, 'c')),
#  ('. .', (222, 'c')),
#  ('. .', (222, 'c')),
#  ('. .', (223, 'c')),
#  ('. .', (223, 'c')),
#  ('. .', (223, 'c')),
#  ('. .', (223, 'c')),
#  ('. .', (223, 'c')),
#  ('. .', (223, 'c')),
#  ('. .', (223, 'c')),
#  ('. .', (224, 'c')),
#  ('. .', (224, 'c')),
#  ('. .', (224, 'c')),
#  ('. .', (224, 'c')),
#  ('. .', (224, 'c')),
#  ('. .', (224, 'c')),
#  ('. .', (224, 'c')),
#  ('. .', (225, 'c')),
#  ('. .', (225, 'c')),
#  ('. .', (225, 'c')),
#  ('. .', (225, 'c')),
#  ('. .', (225, 'c')),
#  ('. .', (225, 'c')),
#  ('. .', (225, 'c')),
#  ('. .', (226, 'c')),
#  ('. .', (226, 'c')),
#  ('. .', (226, 'c')),
#  ('. .', (226, 'c')),
#  ('. .', (226, 'c')),
#  ('. .', (226, 'c')),
#  ('. .', (226, 'c')),
#  ('. .', (227, 'c')),
#  ('. .', (227, 'c')),
#  ('. .', (227, 'c')),
#  ('. .', (227, 'c')),
#  ('. .', (227, 'c')),
#  ('. .', (227, 'c')),
#  ('. .', (227, 'c')),
#  ('. .', (228, 'c')),
#  ('. .', (228, 'c')),
#  ('. .', (228, 'c')),
#  ('. .', (228, 'c')),
#  ('. .', (228, 'c')),
#  ('. .', (228, 'c')),
#  ('. .', (228, 'c')),
#  ('. .', (229, 'c')),
#  ('. .', (229, 'c')),
#  ('. .', (229, 'c')),
#  ('. .', (229, 'c')),
#  ('. .', (229, 'c')),
#  ('. .', (229, 'c')),
#  ('. .', (229, 'c')),
#  ('. .', (230, 'c')),
#  ('. .', (230, 'c')),
#  ('. .', (230, 'c')),
#  ('. .', (230, 'c')),
#  ('. .', (230, 'c')),
#  ('. .', (230, 'c')),
#  ('. .', (230, 'c')),
#  ('. .', (231, 'c')),
#  ('. .', (231, 'c')),
#  ('. .', (231, 'c')),
#  ('. .', (231, 'c')),
#  ('. .', (231, 'c')),
#  ('. .', (231, 'c')),
#  ('. .', (231, 'c')),
#  ('. .', (232, 'c')),
#  ('. .', (232, 'c')),
#  ('. .', (232, 'c')),
#  ('. .', (232, 'c')),
#  ('. .', (232, 'c')),
#  ('. .', (232, 'c')),
#  ('. .', (232, 'c')),
#  ('. .', (233, 'c')),
#  ('. .', (233, 'c')),
#  ('. .', (233, 'c')),
#  ('. .', (233, 'c')),
#  ('. .', (233, 'c')),
#  ('. .', (233, 'c')),
#  ('. .', (233, 'c')),
#  ('. .', (234, 'c')),
#  ('. .', (234, 'c')),
#  ('. .', (234, 'c')),
#  ('. .', (234, 'c')),
#  ('. .', (234, 'c')),
#  ('. .', (234, 'c')),
#  ('. .', (234, 'c')),
#  ('. .', (235, 'c')),
#  ('. .', (235, 'c')),
#  ('. .', (235, 'c')),
#  ('. .', (235, 'c')),
#  ('. .', (235, 'c')),
#  ('. .', (235, 'c')),
#  ('. .', (235, 'c')),
#  ('. .', (236, 'c')),
#  ('. .', (236, 'c')),
#  ('. .', (236, 'c')),
#  ('. .', (236, 'c')),
#  ('. .', (236, 'c')),
#  ('. .', (236, 'c')),
#  ('. .', (236, 'c')),
#  ('. .', (237, 'c')),
#  ('. .', (237, 'c')),
#  ('. .', (237, 'c')),
#  ('. .', (237, 'c')),
#  ('. .', (237, 'c')),
#  ('. .', (237, 'c')),
#  ('. .', (237, 'c')),
#  ('. .', (238, 'c')),
#  ('. .', (238, 'c')),
#  ('. .', (238, 'c')),
#  ('. .', (238, 'c')),
#  ('. .', (238, 'c')),
#  ('. .', (238, 'c')),
#  ('. .', (238, 'c')),
#  ('. .', (239, 'c')),
#  ('. .', (239, 'c')),
#  ('. .', (239, 'c')),
#  ('. .', (239, 'c')),
#  ('. .', (239, 'c')),
#  ('. .', (239, 'c')),
#  ('. .', (239, 'c')),
#  ('. .', (240, 'c')),
#  ('. .', (240, 'c')),
#  ('. .', (240, 'c')),
#  ('. .', (240, 'c')),
#  ('. .', (240, 'c')),
#  ('. .', (240, 'c')),
#  ('. .', (240, 'c')),
#  ('. .', (241, 'c')),
#  ('. .', (241, 'c')),
#  ('. .', (241, 'c')),
#  ('. .', (241, 'c')),
#  ('. .', (241, 'c')),
#  ('. .', (241, 'c')),
#  ('. .', (241, 'c')),
#  ('. .', (242, 'c')),
#  ('. .', (242, 'c')),
#  ('. .', (242, 'c')),
#  ('. .', (242, 'c')),
#  ('. .', (242, 'c')),
#  ('. .', (242, 'c')),
#  ('. .', (242, 'c')),
#  ('. .', (243, 'c')),
#  ('. .', (243, 'c')),
#  ('. .', (243, 'c')),
#  ('. .', (243, 'c')),
#  ('. .', (243, 'c')),
#  ('. .', (243, 'c')),
#  ('. .', (243, 'c')),
#  ('. .', (244, 'c')),
#  ('. .', (244, 'c')),
#  ('. .', (244, 'c')),
#  ('. .', (244, 'c')),
#  ('. .', (244, 'c')),
#  ('. .', (244, 'c')),
#  ('. .', (244, 'c')),
#  ('. .', (245, 'c')),
#  ('. .', (245, 'c')),
#  ('. .', (245, 'c')),
#  ('. .', (245, 'c')),
#  ('. .', (245, 'c')),
#  ('. .', (245, 'c')),
#  ('. .', (245, 'c')),
#  ('. .', (246, 'c')),
#  ('. .', (246, 'c')),
#  ('. .', (246, 'c')),
#  ('. .', (246, 'c')),
#  ('. .', (246, 'c')),
#  ('. .', (246, 'c')),
#  ('. .', (246, 'c')),
#  ('. .', (247, 'c')),
#  ('. .', (247, 'c')),
#  ('. .', (247, 'c')),
#  ('. .', (247, 'c')),
#  ('. .', (247, 'c')),
#  ('. .', (247, 'c')),
#  ('. .', (247, 'c')),
#  ('. .', (248, 'c')),
#  ('. .', (248, 'c')),
#  ('. .', (248, 'c')),
#  ('. .', (248, 'c')),
#  ('. .', (248, 'c')),
#  ('. .', (248, 'c')),
#  ('. .', (248, 'c')),
#  ('. .', (249, 'c')),
#  ('. .', (249, 'c')),
#  ('. .', (249, 'c')),
#  ('. .', (249, 'c')),
#  ('. .', (249, 'c')),
#  ('. .', (249, 'c')),
#  ('. .', (249, 'c')),
#  ('. .', (250, 'c')),
#  ('. .', (250, 'c')),
#  ('. .', (250, 'c')),
#  ('. .', (250, 'c')),
#  ('. .', (250, 'c')),
#  ('. .', (250, 'c')),
#  ('. .', (250, 'c')),
#  ('. .', (251, 'c')),
#  ('. .', (251, 'c')),
#  ('. .', (251, 'c')),
#  ('. .', (251, 'c')),
#  ('. .', (251, 'c')),
#  ('. .', (251, 'c')),
#  ('. .', (251, 'c')),
#  ('. .', (252, 'c')),
#  ('. .', (252, 'c')),
#  ('. .', (252, 'c')),
#  ('. .', (252, 'c')),
#  ('. .', (252, 'c')),
#  ('. .', (252, 'c')),
#  ('. .', (252, 'c')),
#  ('. .', (253, 'c')),
#  ('. .', (253, 'c')),
#  ('. .', (253, 'c')),
#  ('. .', (253, 'c')),
#  ('. .', (253, 'c')),
#  ('. .', (253, 'c')),
#  ('. .', (253, 'c')),
#  ('. .', (254, 'c')),
#  ('. .', (254, 'c')),
#  ('. .', (254, 'c')),
#  ('. .', (254, 'c')),
#  ('. .', (254, 'c')),
#  ('. .', (254, 'c')),
#  ('. .', (254, 'c')),
#  ('. .', (255, 'c')),
#  ('. .', (255, 'c')),
#  ('. .', (255, 'c')),
#  ('. .', (255, 'c')),
#  ('. .', (255, 'c')),
#  ('. .', (255, 'c')),
#  ('. .', (255, 'c')),
#  ('. .', (256, 'c')),
#  ('. .', (256, 'c')),
#  ('. .', (256, 'c')),
#  ('. .', (256, 'c')),
#  ('. .', (256, 'c')),
#  ('. .', (256, 'c')),
#  ('. .', (256, 'c')),
#  ('. .', (257, 'c')),
#  ('. .', (257, 'c')),
#  ('. .', (257, 'c')),
#  ('. .', (257, 'c')),
#  ('. .', (257, 'c')),
#  ('. .', (257, 'c')),
#  ('. .', (257, 'c')),
#  ('. .', (258, 'c')),
#  ('. .', (258, 'c')),
#  ('. .', (258, 'c')),
#  ('. .', (258, 'c')),
#  ('. .', (258, 'c')),
#  ('. .', (258, 'c')),
#  ('. .', (258, 'c')),
#  ('. .', (259, 'c')),
#  ('. .', (259, 'c')),
#  ('. .', (259, 'c')),
#  ('. .', (259, 'c')),
#  ('. .', (259, 'c')),
#  ('. .', (259, 'c')),
#  ('. .', (259, 'c')),
#  ('. .', (260, 'c')),
#  ('. .', (260, 'c')),
#  ('. .', (260, 'c')),
#  ('. .', (260, 'c')),
#  ('. .', (260, 'c')),
#  ('. .', (260, 'c')),
#  ('. .', (260, 'c')),
#  ('. .', (261, 'c')),
#  ('. .', (261, 'c')),
#  ('. .', (261, 'c')),
#  ('. .', (261, 'c')),
#  ('. .', (261, 'c')),
#  ('. .', (261, 'c')),
#  ('. .', (261, 'c')),
#  ('. .', (262, 'c')),
#  ('. .', (262, 'c')),
#  ('. .', (262, 'c')),
#  ('. .', (262, 'c')),
#  ('. .', (262, 'c')),
#  ('. .', (262, 'c')),
#  ('. .', (262, 'c')),
#  ('ab-fubinaca', (178, 'c')),
#  ('ab-fubinaca', (179, 'c')),
#  ('ab-fubinaca', (180, 'c')),
#  ('ab-fubinaca', (181, 'c')),
#  ('ab-fubinaca', (182, 'c')),
#  ('ab-fubinaca', (183, 'c')),
#  ('ab-fubinaca', (184, 'c')),
#  ('ab-fubinaca', (185, 'c')),
#  ('ab-fubinaca', (186, 'c')),
#  ('ab-fubinaca', (187, 'c')),
#  ('ab-fubinaca', (188, 'c')),
#  ('ab-fubinaca', (189, 'c')),
#  ('ab-fubinaca', (190, 'c')),
#  ('ab-fubinaca', (191, 'c')),
#  ('ab-fubinaca', (192, 'c')),
#  ('ab-fubinaca', (193, 'c')),
#  ('ab-fubinaca', (194, 'c')),
#  ('ab-fubinaca', (195, 'c')),
#  ('ab-fubinaca', (196, 'c')),
#  ('ab-fubinaca', (197, 'c')),
#  ('ab-fubinaca', (198, 'c')),
#  ('ab-fubinaca', (199, 'c')),
#  ('ab-fubinaca', (200, 'c')),
#  ('ab-fubinaca', (201, 'c')),
#  ('ab-fubinaca', (202, 'c')),
#  ('ab-fubinaca', (203, 'c')),
#  ('ab-fubinaca', (204, 'c')),
#  ('ab-fubinaca', (205, 'c')),
#  ('ab-fubinaca', (206, 'c')),
#  ('ab-fubinaca', (207, 'c')),
#  ('ab-fubinaca', (208, 'c')),
#  ('ab-fubinaca', (209, 'c')),
#  ('ab-fubinaca', (210, 'c')),
#  ('ab-fubinaca', (211, 'c')),
#  ('ab-fubinaca', (212, 'c')),
#  ('ab-fubinaca', (213, 'c')),
#  ('ab-fubinaca', (214, 'c')),
#  ('ab-fubinaca', (215, 'c')),
#  ('ab-fubinaca', (216, 'c')),
#  ('ab-fubinaca', (217, 'c')),
#  ('ab-fubinaca', (218, 'c')),
#  ('ab-fubinaca', (219, 'c')),
#  ('ab-fubinaca', (220, 'c')),
#  ('ab-fubinaca', (221, 'c')),
#  ('ab-fubinaca', (222, 'c')),
#  ('ab-fubinaca', (223, 'c')),
#  ('ab-fubinaca', (224, 'c')),
#  ('ab-fubinaca', (225, 'c')),
#  ('ab-fubinaca', (226, 'c')),
#  ('ab-fubinaca', (227, 'c')),
#  ('ab-fubinaca', (228, 'c')),
#  ('ab-fubinaca', (229, 'c')),
#  ('ab-fubinaca', (230, 'c')),
#  ('ab-fubinaca', (231, 'c')),
#  ('ab-fubinaca', (232, 'c')),
#  ('ab-fubinaca', (233, 'c')),
#  ('ab-fubinaca', (234, 'c')),
#  ('ab-fubinaca', (235, 'c')),
#  ('ab-fubinaca', (236, 'c')),
#  ('ab-fubinaca', (237, 'c')),
#  ('ab-fubinaca', (238, 'c')),
#  ('ab-fubinaca', (239, 'c')),
#  ('ab-fubinaca', (240, 'c')),
#  ('ab-fubinaca', (241, 'c')),
#  ('ab-fubinaca', (242, 'c')),
#  ('ab-fubinaca', (243, 'c')),
#  ('ab-fubinaca', (244, 'c')),
#  ('ab-fubinaca', (245, 'c')),
#  ('ab-fubinaca', (246, 'c')),
#  ('ab-fubinaca', (247, 'c')),
#  ('ab-fubinaca', (248, 'c')),
#  ('ab-fubinaca', (249, 'c')),
#  ('ab-fubinaca', (250, 'c')),
#  ('ab-fubinaca', (251, 'c')),
#  ('ab-fubinaca', (252, 'c')),
#  ('ab-fubinaca', (253, 'c')),
#  ('ab-fubinaca', (254, 'c')),
#  ('ab-fubinaca', (255, 'c')),
#  ('ab-fubinaca', (256, 'c')),
#  ('ab-fubinaca', (257, 'c')),
#  ('ab-fubinaca', (258, 'c')),
#  ('ab-fubinaca', (259, 'c')),
#  ('ab-fubinaca', (260, 'c')),
#  ('ab-fubinaca', (261, 'c')),
#  ('ab-fubinaca', (262, 'c')),
#  ('abbreviations', (243, 'c')),
#  ('abbreviations', (244, 'c')),
#  ('abbreviations', (245, 'c')),
#  ('abbreviations', (246, 'c')),
#  ('abbreviations', (247, 'c')),
#  ('abbreviations', (248, 'c')),
#  ('abbreviations', (249, 'c')),
#  ('abbreviations', (250, 'c')),
#  ('abbreviations', (251, 'c')),
#  ('abbreviations', (252, 'c')),
#  ('abbreviations', (253, 'c')),
#  ('abbreviations', (254, 'c')),
#  ('abbreviations', (255, 'c')),
#  ('abbreviations', (256, 'c')),
#  ('abbreviations', (257, 'c')),
#  ('abbreviations', (258, 'c')),
#  ('abbreviations', (259, 'c')),
#  ('abbreviations', (260, 'c')),
#  ('abbreviations', (261, 'c')),
#  ('abbreviations', (262, 'c')),
#  ('abdomen', (0, 'c')),
#  ('abdomen', (1, 'c')),
#  ('abdomen', (2, 'c')),
#  ('abdomen', (3, 'c')),
#  ('abdomen', (4, 'c')),
#  ('abdomen', (4, 'c')),
#  ('abdomen', (5, 'c')),
#  ('abdomen', (5, 'c')),
#  ('abdomen', (6, 'c')),
#  ('abdomen', (6, 'c')),
#  ('abdomen', (7, 'c')),
#  ('abdomen', (7, 'c')),
#  ('abdomen', (8, 'c')),
#  ('abdomen', (8, 'c')),
#  ('abdomen', (9, 'c')),
#  ('abdomen', (9, 'c')),
#  ('abdomen', (10, 'c')),
#  ('abdomen', (10, 'c')),
#  ('abdomen', (11, 'c')),
#  ('abdomen', (11, 'c')),
#  ('abdomen', (12, 'c')),
#  ('abdomen', (12, 'c')),
#  ('abdomen', (13, 'c')),
#  ('abdomen', (13, 'c')),
#  ('abdomen', (14, 'c')),
#  ('abdomen', (14, 'c')),
#  ('abdomen', (15, 'c')),
#  ('abdomen', (15, 'c')),
#  ('abdomen', (16, 'c')),
#  ('abdomen', (16, 'c')),
#  ('abdomen', (17, 'c')),
#  ('abdomen', (17, 'c')),
#  ('abdomen', (18, 'c')),
#  ('abdomen', (18, 'c')),
#  ('abdomen', (19, 'c')),
#  ('abdomen', (19, 'c')),
#  ('abdomen', (20, 'c')),
#  ('abdomen', (20, 'c')),
#  ('abdomen', (21, 'c')),
#  ('abdomen', (21, 'c')),
#  ('abdomen', (22, 'c')),
#  ('abdomen', (22, 'c')),
#  ('abdomen', (23, 'c')),
#  ('abdomen', (23, 'c')),
#  ('abdomen', (24, 'c')),
#  ('abdomen', (24, 'c')),
#  ('abdomen', (25, 'c')),
#  ('abdomen', (25, 'c')),
#  ('abdomen', (26, 'c')),
#  ('abdomen', (26, 'c')),
#  ('abdomen', (27, 'c')),
#  ('abdomen', (27, 'c')),
#  ('abdomen', (28, 'c')),
#  ('abdomen', (28, 'c')),
#  ('abdomen', (29, 'c')),
#  ('abdomen', (29, 'c')),
#  ('abdomen', (30, 'c')),
#  ('abdomen', (30, 'c')),
#  ('abdomen', (31, 'c')),
#  ('abdomen', (31, 'c')),
#  ('abdomen', (32, 'c')),
#  ('abdomen', (32, 'c')),
#  ('abdomen', (33, 'c')),
#  ('abdomen', (33, 'c')),
#  ('abdomen', (34, 'c')),
#  ('abdomen', (34, 'c')),
#  ('abdomen', (35, 'c')),
#  ('abdomen', (35, 'c')),
#  ('abdomen', (36, 'c')),
#  ('abdomen', (36, 'c')),
#  ('abdomen', (37, 'c')),
#  ('abdomen', (37, 'c')),
#  ('abdomen', (38, 'c')),
#  ('abdomen', (38, 'c')),
#  ('abdomen', (39, 'c')),
#  ('abdomen', (39, 'c')),
#  ('abdomen', (40, 'c')),
#  ('abdomen', (40, 'c')),
#  ('abdomen', (41, 'c')),
#  ('abdomen', (41, 'c')),
#  ('abdomen', (42, 'c')),
#  ('abdomen', (42, 'c')),
#  ('abdomen', (43, 'c')),
#  ('abdomen', (43, 'c')),
#  ('abdomen', (44, 'c')),
#  ('abdomen', (44, 'c')),
#  ('abdomen', (45, 'c')),
#  ('abdomen', (45, 'c')),
#  ('abdomen', (46, 'c')),
#  ('abdomen', (46, 'c')),
#  ('abdomen', (47, 'c')),
#  ('abdomen', (47, 'c')),
#  ('abdomen', (48, 'c')),
#  ('abdomen', (48, 'c')),
#  ('abdomen', (49, 'c')),
#  ('abdomen', (49, 'c')),
#  ('abdomen', (50, 'c')),
#  ('abdomen', (50, 'c')),
#  ('abdomen', (51, 'c')),
#  ('abdomen', (51, 'c')),
#  ('abdomen', (52, 'c')),
#  ('abdomen', (52, 'c')),
#  ('abdomen', (53, 'c')),
#  ('abdomen', (53, 'c')),
#  ('abdomen', (54, 'c')),
#  ('abdomen', (54, 'c')),
#  ('abdomen', (55, 'c')),
#  ('abdomen', (55, 'c')),
#  ('abdomen', (56, 'c')),
#  ('abdomen', (56, 'c')),
#  ('abdomen', (57, 'c')),
#  ('abdomen', (57, 'c')),
#  ('abdomen', (58, 'c')),
#  ('abdomen', (58, 'c')),
#  ('abdomen', (59, 'c')),
#  ('abdomen', (59, 'c')),
#  ('abdomen', (60, 'c')),
#  ('abdomen', (60, 'c')),
#  ('abdomen', (61, 'c')),
#  ('abdomen', (61, 'c')),
#  ('abdomen', (62, 'c')),
#  ('abdomen', (62, 'c')),
#  ('abdomen', (63, 'c')),
#  ('abdomen', (63, 'c')),
#  ('abdomen', (64, 'c')),
#  ('abdomen', (64, 'c')),
#  ('abdomen', (65, 'c')),
#  ('abdomen', (65, 'c')),
#  ('abdomen', (66, 'c')),
#  ('abdomen', (66, 'c')),
#  ('abdomen', (67, 'c')),
#  ('abdomen', (67, 'c')),
#  ('abdomen', (68, 'c')),
#  ('abdomen', (68, 'c')),
#  ('abdomen', (69, 'c')),
#  ('abdomen', (69, 'c')),
#  ('abdomen', (70, 'c')),
#  ('abdomen', (70, 'c')),
#  ('abdomen', (71, 'c')),
#  ('abdomen', (71, 'c')),
#  ('abdomen', (72, 'c')),
#  ('abdomen', (72, 'c')),
#  ('abdomen', (73, 'c')),
#  ('abdomen', (73, 'c')),
#  ('abdomen', (74, 'c')),
#  ('abdomen', (74, 'c')),
#  ('abdomen', (75, 'c')),
#  ('abdomen', (75, 'c')),
#  ('abdomen', (76, 'c')),
#  ('abdomen', (76, 'c')),
#  ('abdomen', (77, 'c')),
#  ('abdomen', (77, 'c')),
#  ('abdomen', (78, 'c')),
#  ('abdomen', (78, 'c')),
#  ('abdomen', (79, 'c')),
#  ('abdomen', (79, 'c')),
#  ('abdomen', (80, 'c')),
#  ('abdomen', (80, 'c')),
#  ('abdomen', (81, 'c')),
#  ('abdomen', (81, 'c')),
#  ('abdomen', (82, 'c')),
#  ('abdomen', (82, 'c')),
#  ('abdomen', (83, 'c')),
#  ('abdomen', (83, 'c')),
#  ('abdomen', (84, 'c')),
#  ('abdomen', (84, 'c')),
#  ('abdomen', (85, 'c')),
#  ('abdomen', (85, 'c')),
#  ('abdomen', (86, 'c')),
#  ('abdomen', (86, 'c')),
#  ('abdomen', (87, 'c')),
#  ('abdomen', (87, 'c')),
#  ('abdomen', (88, 'c')),
#  ('abdomen', (88, 'c')),
#  ('abdomen', (89, 'c')),
#  ('abdomen', (89, 'c')),
#  ('abdomen', (90, 'c')),
#  ('abdomen', (90, 'c')),
#  ('abdomen', (91, 'c')),
#  ('abdomen', (91, 'c')),
#  ('abdomen', (92, 'c')),
#  ('abdomen', (92, 'c')),
#  ('abdomen', (93, 'c')),
#  ('abdomen', (93, 'c')),
#  ('abdomen', (94, 'c')),
#  ('abdomen', (94, 'c')),
#  ('abdomen', (95, 'c')),
#  ('abdomen', (95, 'c')),
#  ('abdomen', (96, 'c')),
#  ('abdomen', (96, 'c')),
#  ('abdomen', (97, 'c')),
#  ('abdomen', (97, 'c')),
#  ('abdomen', (98, 'c')),
#  ('abdomen', (98, 'c')),
#  ('abdomen', (99, 'c')),
#  ('abdomen', (99, 'c')),
#  ('abdomen', (100, 'c')),
#  ('abdomen', (100, 'c')),
#  ('abdomen', (101, 'c')),
#  ('abdomen', (101, 'c')),
#  ('abdomen', (102, 'c')),
#  ('abdomen', (102, 'c')),
#  ('abdomen', (103, 'c')),
#  ('abdomen', (103, 'c')),
#  ('abdomen', (104, 'c')),
#  ('abdomen', (104, 'c')),
#  ('abdomen', (105, 'c')),
#  ('abdomen', (105, 'c')),
#  ('abdomen', (106, 'c')),
#  ('abdomen', (106, 'c')),
#  ('abdomen', (107, 'c')),
#  ('abdomen', (107, 'c')),
#  ('abdomen', (108, 'c')),
#  ('abdomen', (108, 'c')),
#  ('abdomen', (109, 'c')),
#  ('abdomen', (109, 'c')),
#  ('abdomen', (110, 'c')),
#  ('abdomen', (110, 'c')),
#  ('abdomen', (111, 'c')),
#  ('abdomen', (111, 'c')),
#  ('abdomen', (112, 'c')),
#  ('abdomen', (112, 'c')),
#  ('abdomen', (113, 'c')),
#  ('abdomen', (113, 'c')),
#  ('abdomen', (114, 'c')),
#  ('abdomen', (114, 'c')),
#  ('abdomen', (115, 'c')),
#  ('abdomen', (115, 'c')),
#  ('abdomen', (116, 'c')),
#  ('abdomen', (116, 'c')),
#  ('abdomen', (117, 'c')),
#  ('abdomen', (117, 'c')),
#  ('abdomen', (118, 'c')),
#  ('abdomen', (118, 'c')),
#  ('abdomen', (119, 'c')),
#  ('abdomen', (119, 'c')),
#  ('abdomen', (120, 'c')),
#  ('abdomen', (120, 'c')),
#  ('abdomen', (121, 'c')),
#  ('abdomen', (121, 'c')),
#  ('abdomen', (122, 'c')),
#  ('abdomen', (122, 'c')),
#  ('abdomen', (123, 'c')),
#  ('abdomen', (123, 'c')),
#  ('abdomen', (124, 'c')),
#  ('abdomen', (124, 'c')),
#  ('abdomen', (125, 'c')),
#  ('abdomen', (125, 'c')),
#  ('abdomen', (126, 'c')),
#  ('abdomen', (126, 'c')),
#  ('abdomen', (127, 'c')),
#  ('abdomen', (127, 'c')),
#  ('abdomen', (128, 'c')),
#  ('abdomen', (128, 'c')),
#  ('abdomen', (129, 'c')),
#  ('abdomen', (129, 'c')),
#  ('abdomen', (130, 'c')),
#  ('abdomen', (130, 'c')),
#  ('abdomen', (131, 'c')),
#  ('abdomen', (131, 'c')),
#  ('abdomen', (132, 'c')),
#  ('abdomen', (132, 'c')),
#  ('abdomen', (133, 'c')),
#  ('abdomen', (133, 'c')),
#  ('abdomen', (134, 'c')),
#  ('abdomen', (134, 'c')),
#  ('abdomen', (135, 'c')),
#  ('abdomen', (135, 'c')),
#  ('abdomen', (136, 'c')),
#  ('abdomen', (136, 'c')),
#  ('abdomen', (137, 'c')),
#  ('abdomen', (137, 'c')),
#  ('abdomen', (138, 'c')),
#  ('abdomen', (138, 'c')),
#  ('abdomen', (139, 'c')),
#  ('abdomen', (139, 'c')),
#  ('abdomen', (140, 'c')),
#  ('abdomen', (140, 'c')),
#  ('abdomen', (141, 'c')),
#  ('abdomen', (141, 'c')),
#  ('abdomen', (142, 'c')),
#  ('abdomen', (142, 'c')),
#  ('abdomen', (143, 'c')),
#  ('abdomen', (143, 'c')),
#  ('abdomen', (144, 'c')),
#  ('abdomen', (144, 'c')),
#  ('abdomen', (145, 'c')),
#  ('abdomen', (145, 'c')),
#  ('abdomen', (146, 'c')),
#  ('abdomen', (146, 'c')),
#  ('abdomen', (147, 'c')),
#  ('abdomen', (147, 'c')),
#  ('abdomen', (148, 'c')),
#  ('abdomen', (148, 'c')),
#  ('abdomen', (149, 'c')),
#  ('abdomen', (149, 'c')),
#  ('abdomen', (150, 'c')),
#  ('abdomen', (150, 'c')),
#  ('abdomen', (151, 'c')),
#  ('abdomen', (151, 'c')),
#  ('abdomen', (152, 'c')),
#  ('abdomen', (152, 'c')),
#  ('abdomen', (153, 'c')),
#  ('abdomen', (153, 'c')),
#  ('abdomen', (154, 'c')),
#  ('abdomen', (154, 'c')),
#  ('abdomen', (155, 'c')),
#  ('abdomen', (155, 'c')),
#  ('abdomen', (156, 'c')),
#  ('abdomen', (156, 'c')),
#  ('abdomen', (157, 'c')),
#  ('abdomen', (157, 'c')),
#  ('abdomen', (158, 'c')),
#  ('abdomen', (158, 'c')),
#  ('abdomen', (159, 'c')),
#  ('abdomen', (159, 'c')),
#  ('abdomen', (160, 'c')),
#  ('abdomen', (160, 'c')),
#  ('abdomen', (161, 'c')),
#  ('abdomen', (161, 'c')),
#  ('abdomen', (162, 'c')),
#  ('abdomen', (162, 'c')),
#  ('abdomen', (163, 'c')),
#  ('abdomen', (163, 'c')),
#  ('abdomen', (164, 'c')),
#  ('abdomen', (164, 'c')),
#  ('abdomen', (165, 'c')),
#  ('abdomen', (165, 'c')),
#  ('abdomen', (166, 'c')),
#  ('abdomen', (166, 'c')),
#  ('abdomen', (167, 'c')),
#  ('abdomen', (167, 'c')),
#  ('abdomen', (168, 'c')),
#  ('abdomen', (168, 'c')),
#  ('abdomen', (169, 'c')),
#  ('abdomen', (169, 'c')),
#  ('abdomen', (170, 'c')),
#  ('abdomen', (170, 'c')),
#  ('abdomen', (171, 'c')),
#  ('abdomen', (171, 'c')),
#  ('abdomen', (172, 'c')),
#  ('abdomen', (172, 'c')),
#  ('abdomen', (173, 'c')),
#  ('abdomen', (173, 'c')),
#  ('abdomen', (174, 'c')),
#  ('abdomen', (174, 'c')),
#  ('abdomen', (175, 'c')),
#  ('abdomen', (175, 'c')),
#  ('abdomen', (176, 'c')),
#  ('abdomen', (176, 'c')),
#  ('abdomen', (177, 'c')),
#  ('abdomen', (177, 'c')),
#  ('abdomen', (178, 'c')),
#  ('abdomen', (178, 'c')),
#  ('abdomen', (179, 'c')),
#  ('abdomen', (179, 'c')),
#  ('abdomen', (180, 'c')),
#  ('abdomen', (180, 'c')),
#  ('abdomen', (181, 'c')),
#  ('abdomen', (181, 'c')),
#  ('abdomen', (182, 'c')),
#  ('abdomen', (182, 'c')),
#  ('abdomen', (183, 'c')),
#  ('abdomen', (183, 'c')),
#  ('abdomen', (184, 'c')),
#  ('abdomen', (184, 'c')),
#  ('abdomen', (185, 'c')),
#  ('abdomen', (185, 'c')),
#  ('abdomen', (186, 'c')),
#  ('abdomen', (186, 'c')),
#  ('abdomen', (187, 'c')),
#  ('abdomen', (187, 'c')),
#  ('abdomen', (188, 'c')),
#  ('abdomen', (188, 'c')),
#  ('abdomen', (189, 'c')),
#  ('abdomen', (189, 'c')),
#  ('abdomen', (190, 'c')),
#  ('abdomen', (190, 'c')),
#  ('abdomen', (191, 'c')),
#  ('abdomen', (191, 'c')),
#  ('abdomen', (192, 'c')),
#  ('abdomen', (192, 'c')),
#  ('abdomen', (193, 'c')),
#  ('abdomen', (193, 'c')),
#  ('abdomen', (194, 'c')),
#  ('abdomen', (194, 'c')),
#  ('abdomen', (195, 'c')),
#  ('abdomen', (195, 'c')),
#  ('abdomen', (196, 'c')),
#  ('abdomen', (196, 'c')),
#  ('abdomen', (197, 'c')),
#  ('abdomen', (197, 'c')),
#  ('abdomen', (198, 'c')),
#  ('abdomen', (198, 'c')),
#  ('abdomen', (199, 'c')),
#  ('abdomen', (199, 'c')),
#  ('abdomen', (200, 'c')),
#  ('abdomen', (200, 'c')),
#  ('abdomen', (201, 'c')),
#  ('abdomen', (201, 'c')),
#  ('abdomen', (202, 'c')),
#  ('abdomen', (202, 'c')),
#  ('abdomen', (203, 'c')),
#  ('abdomen', (203, 'c')),
#  ('abdomen', (204, 'c')),
#  ('abdomen', (204, 'c')),
#  ('abdomen', (205, 'c')),
#  ('abdomen', (205, 'c')),
#  ('abdomen', (206, 'c')),
#  ('abdomen', (206, 'c')),
#  ('abdomen', (207, 'c')),
#  ('abdomen', (207, 'c')),
#  ('abdomen', (208, 'c')),
#  ('abdomen', (208, 'c')),
#  ('abdomen', (209, 'c')),
#  ('abdomen', (209, 'c')),
#  ('abdomen', (210, 'c')),
#  ('abdomen', (210, 'c')),
#  ('abdomen', (211, 'c')),
#  ('abdomen', (211, 'c')),
#  ('abdomen', (212, 'c')),
#  ('abdomen', (212, 'c')),
#  ('abdomen', (213, 'c')),
#  ('abdomen', (213, 'c')),
#  ('abdomen', (214, 'c')),
#  ('abdomen', (214, 'c')),
#  ('abdomen', (215, 'c')),
#  ('abdomen', (215, 'c')),
#  ('abdomen', (216, 'c')),
#  ('abdomen', (216, 'c')),
#  ('abdomen', (217, 'c')),
#  ('abdomen', (217, 'c')),
#  ('abdomen', (218, 'c')),
#  ('abdomen', (218, 'c')),
#  ('abdomen', (219, 'c')),
#  ('abdomen', (219, 'c')),
#  ('abdomen', (220, 'c')),
#  ('abdomen', (220, 'c')),
#  ('abdomen', (221, 'c')),
#  ('abdomen', (221, 'c')),
#  ('abdomen', (222, 'c')),
#  ('abdomen', (222, 'c')),
#  ('abdomen', (223, 'c')),
#  ('abdomen', (223, 'c')),
#  ('abdomen', (224, 'c')),
#  ...]

# %%
from string import punctuation
import re
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

text1 = "A visual evaluation of the ability of the scaled PBPK model to predict MVG pharmacokinetics after oral administration of a 15-mg dose in children aged from 3 to 11 years. <em>Open circles</em> are observed concentrations plotted across time, the <em>dashed red lines</em> are the 5th, 50th and 95th percentiles of the concentrations simulated with the WBPBPK model from Wendling <em>et al.</em> (<a href=\"#CR9\" rid=\"CR9\" class=\" bibr popnode\">9</a>), the <em>solid blue lines</em> are the 5th, 50th and 95th percentiles of the concentrations simulated with the reduced PBPK model (STATMOD 1), and the <em>horizontal dotted line</em> represents the lower limit of quantification of the assay"
text2 = "A visual evaluation of the ability of the scaled PBPK model to predict MVG pharmacokinetics after oral administration of a 15-mg dose in children aged from 3 to 11 years. "

def cleanText(text):
    filterTokens= []
    text = text.lower()
    #print(text)
    remNumb = re.sub('[0-9]+', '', text)
    #print("no numbers")
    #print(remNumb)
    remTags = re.sub("\<+/*\w*/*\>+", '', remNumb) 
    #print("no tags")
    #print(remTags)
    
    tokenzier = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(remTags)
    for t in tokens:
        if t not in punctuation:
            filterTokens.append(t)
            #print(t)
    #filterTokens = [token for token in tokens if not token in punctuation ]
    #print(filterTokens[1])

    return filterTokens

print('--------------------------------------------------')
resText = []
resText = cleanText(text1)
print(resText)
print('--------------------------------------------------')
# Out:
# --------------------------------------------------
# ['a', 'visual', 'evaluation', 'of', 'the', 'ability', 'of', 'the', 'scaled', 'pbpk', 'model', 'to', 'predict', 'mvg', 'pharmacokinetics', 'after', 'oral', 'administration', 'of', 'a', 'mg', 'dose', 'in', 'children', 'aged', 'from', 'to', 'years', 'open', 'circles', 'are', 'observed', 'concentrations', 'plotted', 'across', 'time', 'the', 'dashed', 'red', 'lines', 'are', 'the', 'th', 'th', 'and', 'th', 'percentiles', 'of', 'the', 'concentrations', 'simulated', 'with', 'the', 'wbpbpk', 'model', 'from', 'wendling', 'et', 'al', 'a', 'href', '#cr', 'rid', 'cr', 'class', 'bibr', 'popnode', 'the', 'solid', 'blue', 'lines', 'are', 'the', 'th', 'th', 'and', 'th', 'percentiles', 'of', 'the', 'concentrations', 'simulated', 'with', 'the', 'reduced', 'pbpk', 'model', 'statmod', 'and', 'the', 'horizontal', 'dotted', 'line', 'represents', 'the', 'lower', 'limit', 'of', 'quantification', 'of', 'the', 'assay']
# --------------------------------------------------

# %%
# constructing inverted index

invertedIdx = {}

for i, doc in enumerate(docs):
    for term in doc.split():
        if term in invertedIdx:
            invertedIdx[term].add(i)
        else:
            invertedIdx[term] = {i}
invertedIdx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-a6cbcbc0415d> in <module>()
#       3 invertedIdx = {}
#       4
# ----> 5 for i, doc in enumerate(docs):
#       6     for term in doc.split():
#       7         if term in invertedIdx:
#
# NameError: name 'docs' is not defined

# %%
postingList = invertedIdx['ball']
postingList
# Out:
# {0, 1}

# %%
# Boolean operations:

# %%
def orPostings(posting1, posting2):
    p1 = 0
    p2 = 0
    result = list()
    n1 = len(posting1)
    n2 = len(posting2)
    while p1 < n1 and p2 <n2:
        if posting1[p1] == posting2[p2]:
            result.append(posting1[p1])
            p1 += 1
            p2 += 1
        elif posting1[p1] >posting2[p2]:
            result.append(posting2[p2])
            p2 += 1
        else:
            result.append(posting1[p1])
            p1 += 1
    while p1 < n1:
        result.append(posting1[p1])
        p1 += 1
    while p2 < n2:
        result.append(posting2[p2])
        p2 += 1
    return result

# %%
pl_1 = list(invertedIdx['soccer'])
pl_2 = list(invertedIdx['glider'])
orPostings(pl_1, pl_2)
# Out:
# [0, 1, 2]

# %%
def andPostings(posting1, posting2):
    p1 = 0
    p2 = 0
    n1 = len(posting1)
    n2 = len(posting2)
    result = list()
    
    while p1 < n1 and p2 < n2:
        if posting1[p1] == posting2[p2]:
            result.append(posting1[p1])
            p1 += 1
            p2 += 1
        elif posting1[p1] > posting2[p2]:
            p2 += 1
        else:
            p1 += 1
            
    return result

# %%
pl_1 = list(invertedIdx['soccer'])
pl_2 = list(invertedIdx['ball'])
andPostings(pl_1, pl_2)
# Out:
# [0, 1]
