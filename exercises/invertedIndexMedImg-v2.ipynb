# %%
### imports
import json
from copy import deepcopy

from nltk.tokenize import sent_tokenize, TweetTokenizer
from string import punctuation
import re
import regex
tokenizer = TweetTokenizer()
from nltk.corpus import stopwords
stopW = stopwords.words('english')
# stopW = ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', 'her', 'here', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'i', 'if', 'in', 'into', 'is', 'isn', "isn't", 'it', "it's", 'its', 'itself', 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she's", 'should', "should've", 'shouldn', "shouldn't", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', 'were', 'weren', "weren't", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", "you're", "you've", 'your', 'yours', 'yourself', 'yourselves']
# print(sorted(stopW))

# %%
### a method to Read a json file with img captions and article titles and parse it into set of documents

def getDocs(sourcePath):
    medDocs = []
    sourceFile = open(sourcePath, 'r')

    count = 1
    for line in sourceFile:
        medDocs.append(json.loads(line))
        count += 1

    sourceFile.close()
    
    # for k in range(1,count):
    #     print(str(k) + " : " + medDocs[k]['docId'])
    return medDocs


sourcePath = 'assets/medImages_v0.jl'
medDocs = getDocs(sourcePath)
medDocs[262]
# Out:
# {'articleId': 'PMC7282154',
#  'image_path': 'PMC7282154-6_i2376-0605-6-2-e50-f06.jpg',
#  'image_url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7282154/bin/i2376-0605-6-2-e50-f06.jpg',
#  'articleUrl': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7282154/',
#  'articleTitle': 'RECURRENT INVASIVE DUCTAL BREAST CARCINOMA PRESENTING AS PRIMARY ADRENAL INSUFFICIENCY WITH ADRENAL CRISIS',
#  'caption': 'Histologic section of adrenal metastatic disease (hematoxylin and eosin, Г—100). Tumor cells arranged in solid nests infiltrating lymph node tissue.'}

# %%
# method that cleans the title and caption text in each document
# the result is tokenized titles and caption without unwanted brackets, numbers, spaces, tags, unicode charts;
# result includes no punctuation and stopwards and tokens with length less than 2 symbols
# all tokens are lower case


def preprocessContent(content):
    sentences = sent_tokenize(content)
    tokens = []
    for sent in sentences:
        # removes unicode
        cleanedTokens = re.sub(r'[^\x00-\x7F]+', ' ', sent)
        # removes menions
        cleanedTokens = re.sub(r'@\w+', '', cleanedTokens)
        # removes numbers
#         cleanedTokens = re.sub('[0-9]+', '', cleanedTokens)
        # removes nested brackets 
        cleanedTokens = regex.sub(r'\([^()]*+(?:(?R)[^()]*)*+\)', '', cleanedTokens) 
        # removes nested currly brackets
        cleanedTokens = regex.sub('\{(?:[^}{]|\{[^}{]*\})*\}', '', cleanedTokens) 
        # removes html tags
        cleanedTokens = re.sub('\<+/*\w*/*\>+', '', cleanedTokens)
        # removes punctuation
        cleanedTokens = re.sub(r'[%s]' % re.escape(punctuation), ' ', cleanedTokens)
        # removes doubled spaces
        cleanedTokens = re.sub(r'\s{2,}', ' ', cleanedTokens)
        sentTokens = tokenizer.tokenize(cleanedTokens)
        # lower case each token and removes tokens with length less than 2
        sentTokens = [tok.lower() for tok in sentTokens if len(tok) >2]
        # removes stop words 
        sentTokens2 = [tok for tok in sentTokens if not tok.lower() in stopW ]
        tokens += sentTokens2
    return tokens


def cleanDocs(medDocs):
    cleanedDocs = deepcopy(medDocs)
    for i, doc in enumerate(cleanedDocs):
        doc['articleTitle'] = preprocessContent(doc['articleTitle'] )
        doc['caption'] = preprocessContent(doc['caption'])
    return cleanedDocs

cleanedDocs = cleanDocs(medDocs)

# %%
print(len(cleanedDocs))
print(medDocs[262]['caption'])
print(cleanedDocs[262]['caption'])
# cleanedDocs[262]
# Out:
# 263
# Histologic section of adrenal metastatic disease (hematoxylin and eosin, Г—100). Tumor cells arranged in solid nests infiltrating lymph node tissue.
# ['histologic', 'section', 'adrenal', 'metastatic', 'disease', 'tumor', 'cells', 'arranged', 'solid', 'nests', 'infiltrating', 'lymph', 'node', 'tissue']

# %%
# constructing inverted index
def getInvertedIdx(medDocs):
    invertedIdx = {}

    for i, doc in enumerate(medDocs):
        for term in doc['articleTitle']:
            if term in invertedIdx:
                invertedIdx[term].add((doc['articleId'],'t'))
            else:
                invertedIdx[term] = {(doc['articleId'],'t')}
        for term in doc['caption']:
            if term in invertedIdx:
                invertedIdx[term].add((doc['articleId'],'c'))
            else:
                invertedIdx[term] = {(doc['articleId'],'c')}
    return invertedIdx
           
termInvIdx = getInvertedIdx(cleanedDocs)
termInvIdx
# Out:
# {'novel': {('PMC4706273', 't'),
#   ('PMC4706278', 't'),
#   ('PMC4706287', 't'),
#   ('PMC4779106', 'c'),
#   ('PMC4779108', 't'),
#   ('PMC7279775', 't'),
#   ('PMC7279778', 't'),
#   ('PMC7282159', 't')},
#  'use': {('PMC4706274', 'c'),
#   ('PMC4706274', 't'),
#   ('PMC4779104', 'c'),
#   ('PMC7279778', 't')},
#  'stereotactic': {('PMC7279778', 'c'), ('PMC7279778', 't')},
#  'radiotherapy': {('PMC7279778', 'c'), ('PMC7279778', 't')},
#  'remnant': {('PMC7279778', 't')},
#  'adrenal': {('PMC7279778', 'c'),
#   ('PMC7279778', 't'),
#   ('PMC7282148', 'c'),
#   ('PMC7282154', 'c'),
#   ('PMC7282154', 't'),
#   ('PMC7282157', 'c'),
#   ('PMC7282157', 't')},
#  'tissue': {('PMC4706291', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7279778', 't'),
#   ('PMC7282154', 'c'),
#   ('PMC7282159', 'c')},
#  'nelson': {('PMC4779109', 'c'), ('PMC7279778', 't')},
#  'syndrome': {('PMC7279770', 't'),
#   ('PMC7279778', 't'),
#   ('PMC7282157', 't'),
#   ('PMC7282159', 'c')},
#  'radiation': {('PMC4706291', 'c'), ('PMC7279778', 'c')},
#  'planning': {('PMC7279778', 'c')},
#  'depicted': {('PMC7279778', 'c')},
#  'computed': {('PMC7279770', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282154', 'c'),
#   ('PMC7282157', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7282159', 'c')},
#  'tomography': {('PMC7279770', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282154', 'c'),
#   ('PMC7282157', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7282159', 'c')},
#  'scan': {('PMC7279774', 'c'), ('PMC7279778', 'c'), ('PMC7282159', 'c')},
#  'abdomen': {('PMC7279770', 'c'), ('PMC7279778', 'c'), ('PMC7282159', 'c')},
#  'planned': {('PMC7279778', 'c')},
#  'target': {('PMC4706274', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7583548', 'c')},
#  'volume': {('PMC4706288', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7583549', 'c')},
#  'sbrt': {('PMC7279778', 'c')},
#  'included': {('PMC4706273', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779105', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7583549', 'c')},
#  'safety': {('PMC7279778', 'c')},
#  'margin': {('PMC4706275', 'c'), ('PMC7279778', 'c')},
#  'around': {('PMC4706293', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282159', 'c')},
#  'radiologic': {('PMC7279778', 'c')},
#  'abnormality': {('PMC7279778', 'c')},
#  'organs': {('PMC4706283', 'c'), ('PMC7279778', 'c')},
#  'risk': {('PMC4779106', 'c'), ('PMC7279778', 'c')},
#  'damage': {('PMC7279778', 'c')},
#  'treatment': {('PMC4706277', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279771', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282150', 'c'),
#   ('PMC7282150', 't')},
#  'bilateral': {('PMC7279768', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282151', 'c'),
#   ('PMC7282154', 'c'),
#   ('PMC7282157', 'c'),
#   ('PMC7282157', 't')},
#  'kidneys': {('PMC4706291', 'c'), ('PMC7279778', 'c')},
#  'spinal': {('PMC7279778', 'c')},
#  'cord': {('PMC7279778', 'c')},
#  'stomach': {('PMC7279778', 'c')},
#  'bowel': {('PMC7279778', 'c')},
#  'liver': {('PMC4706278', 'c'),
#   ('PMC4706278', 't'),
#   ('PMC4706291', 'c'),
#   ('PMC7279778', 'c')},
#  'image': {('PMC7279778', 'c'), ('PMC7282148', 'c'), ('PMC7282159', 'c')},
#  'shows': {('PMC4706274', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7583549', 'c')},
#  'orientation': {('PMC7279778', 'c')},
#  'beam': {('PMC7279778', 'c')},
#  'arcs': {('PMC7279778', 'c')},
#  'one': {('PMC4706274', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4706286', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7583549', 'c')},
#  'clockwise': {('PMC7279778', 'c'), ('PMC7583549', 'c')},
#  'counterclockwise': {('PMC7279778', 'c')},
#  'partial': {('PMC4779113', 'c'), ('PMC7279778', 'c')},
#  'arc': {('PMC7279778', 'c')},
#  'arrangement': {('PMC7279778', 'c')},
#  'utilized': {('PMC7279778', 'c')},
#  'treat': {('PMC4706284', 'c'), ('PMC4706291', 'c'), ('PMC7279778', 'c')},
#  'beds': {('PMC7279778', 'c')},
#  'treated': {('PMC4706277', 't'),
#   ('PMC4779100', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279768', 't'),
#   ('PMC7279776', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7583548', 'c')},
#  '900': {('PMC4706287', 'c'), ('PMC7279778', 'c')},
#  'cgy': {('PMC7279778', 'c')},
#  'fractions': {('PMC7279778', 'c')},
#  'dose': {('PMC4706282', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7583549', 'c')},
#  'color': {('PMC4706286', 'c'), ('PMC7279778', 'c')},
#  'wash': {('PMC7279778', 'c')},
#  'approximately': {('PMC4706281', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7583549', 'c')},
#  'level': {('PMC4706278', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7583549', 'c')},
#  'rapid': {('PMC4706292', 'c'), ('PMC7279778', 'c')},
#  'fall': {('PMC4706274', 'c'), ('PMC4706292', 'c'), ('PMC7279778', 'c')},
#  'excellent': {('PMC7279778', 'c')},
#  'sparing': {('PMC7279778', 'c')},
#  'oars': {('PMC7279778', 'c')},
#  'body': {('PMC4706273', 'c'),
#   ('PMC4706276', 'c'),
#   ('PMC4706283', 't'),
#   ('PMC4706288', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 't'),
#   ('PMC4779094', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282159', 'c')},
#  'graph': {('PMC7279778', 'c'), ('PMC7282148', 'c'), ('PMC7583549', 'c')},
#  'changes': {('PMC4706276', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282150', 'c'),
#   ('PMC7282157', 'c')},
#  'serum': {('PMC4706273', 'c'),
#   ('PMC4706274', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7279778', 'c')},
#  'cortisol': {('PMC7279778', 'c')},
#  'plasma': {('PMC4706280', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779099', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7279771', 'c'),
#   ('PMC7279771', 't'),
#   ('PMC7279778', 'c'),
#   ('PMC7583549', 'c')},
#  'acth': {('PMC7279778', 'c')},
#  'levels': {('PMC4706274', 'c'),
#   ('PMC4706275', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779102', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7279771', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'time': {('PMC4706273', 'c'),
#   ('PMC4706275', 'c'),
#   ('PMC4706276', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779099', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282150', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7583548', 'c'),
#   ('PMC7583549', 'c')},
#  'chronology': {('PMC7279778', 'c')},
#  'reference': {('PMC4779113', 'c'), ('PMC4779113', 't'), ('PMC7279778', 'c')},
#  'adrenocortico': {('PMC7279778', 'c')},
#  'tropic': {('PMC7279778', 'c')},
#  'hormone': {('PMC4706292', 'c'),
#   ('PMC7279778', 'c'),
#   ('PMC7282152', 'c'),
#   ('PMC7583549', 'c')},
#  'manifestations': {('PMC7279770', 't')},
#  'glucagonoma': {('PMC7279770', 't')},
#  'migratory': {('PMC7279770', 'c')},
#  'necrolytic': {('PMC7279770', 'c')},
#  'erythema': {('PMC7279770', 'c')},
#  'face': {('PMC7279770', 'c'), ('PMC7282159', 'c')},
#  'showing': {('PMC4706285', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7279770', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7279774', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282151', 'c'),
#   ('PMC7282155', 'c'),
#   ('PMC7282157', 'c'),
#   ('PMC7282159', 'c')},
#  'hyperpigmented': {('PMC7279770', 'c')},
#  'erythematous': {('PMC7279770', 'c')},
#  'lesions': {('PMC7279770', 'c')},
#  'cheilitis': {('PMC7279770', 'c')},
#  'glossitis': {('PMC7279770', 'c')},
#  'axial': {('PMC7279770', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7282159', 'c')},
#  'masses': {('PMC7279770', 'c'), ('PMC7282157', 'c')},
#  'pancreatic': {('PMC7279770', 'c')},
#  'tail': {('PMC7279770', 'c'), ('PMC7583549', 'c')},
#  'right': {('PMC4706275', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7279770', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282155', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'hepatic': {('PMC7279770', 'c')},
#  'lobe': {('PMC7279770', 'c'), ('PMC7279774', 'c')},
#  'histology': {('PMC7279770', 'c')},
#  'nodular': {('PMC7279770', 'c'), ('PMC7282159', 'c')},
#  'trabecular': {('PMC7279770', 'c')},
#  'structures': {('PMC4779098', 'c'),
#   ('PMC4779099', 'c'),
#   ('PMC4779105', 'c'),
#   ('PMC7279770', 'c')},
#  'formed': {('PMC7279770', 'c')},
#  'cells': {('PMC4706273', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706278', 't'),
#   ('PMC4706291', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7279770', 'c'),
#   ('PMC7282154', 'c'),
#   ('PMC7282159', 'c')},
#  'broad': {('PMC7279770', 'c')},
#  'granular': {('PMC7279770', 'c')},
#  'eosinophilic': {('PMC7279770', 'c')},
#  'cytoplasm': {('PMC7279770', 'c')},
#  'homogeneous': {('PMC4779111', 'c'), ('PMC7279770', 'c')},
#  'nuclei': {('PMC7279770', 'c')},
#  'slight': {('PMC7279770', 'c'), ('PMC7279773', 'c')},
#  'pleomorphism': {('PMC7279770', 'c')},
#  'visible': {('PMC7279770', 'c')},
#  'nucleoli': {('PMC7279770', 'c')},
#  'also': {('PMC4706274', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779105', 'c'),
#   ('PMC7279770', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'observed': {('PMC4706274', 'c'),
#   ('PMC4706275', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779094', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279770', 'c'),
#   ('PMC7583549', 'c')},
#  'important': {('PMC7279770', 'c'), ('PMC7282159', 'c')},
#  'mitotic': {('PMC7279770', 'c')},
#  'activity': {('PMC4706278', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC7279770', 'c'),
#   ('PMC7583549', 'c')},
#  'case': {('PMC4706274', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779098', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC7279776', 't'),
#   ('PMC7282148', 't'),
#   ('PMC7282151', 'c'),
#   ('PMC7282151', 't'),
#   ('PMC7282152', 't'),
#   ('PMC7282158', 't'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'acquired': {('PMC7279776', 'c'), ('PMC7279776', 't')},
#  'generalized': {('PMC7279776', 'c'),
#   ('PMC7279776', 't'),
#   ('PMC7282159', 'c'),
#   ('PMC7282159', 't')},
#  'lipodystrophy': {('PMC7279776', 'c'),
#   ('PMC7279776', 't'),
#   ('PMC7282159', 't')},
#  'associated': {('PMC4706288', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC7279776', 't'),
#   ('PMC7282157', 't'),
#   ('PMC7282159', 't')},
#  'pembrolizumab': {('PMC7279776', 'c'), ('PMC7279776', 't')},
#  'patient': {('PMC4706274', 'c'),
#   ('PMC4706275', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC7279776', 't'),
#   ('PMC7282150', 'c'),
#   ('PMC7282152', 'c'),
#   ('PMC7282159', 'c')},
#  'metastatic': {('PMC7279776', 't'),
#   ('PMC7282154', 'c'),
#   ('PMC7282155', 't'),
#   ('PMC7282158', 'c')},
#  'malignant': {('PMC7279776', 't')},
#  'melanoma': {('PMC4706273', 'c'), ('PMC7279776', 't')},
#  'clinical': {('PMC4706293', 'c'),
#   ('PMC4706293', 't'),
#   ('PMC4779096', 't'),
#   ('PMC4779104', 't'),
#   ('PMC7279776', 'c'),
#   ('PMC7282150', 't')},
#  'features': {('PMC4706292', 'c'), ('PMC7279776', 'c'), ('PMC7282159', 't')},
#  'induced': {('PMC4706278', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC4779111', 't'),
#   ('PMC7279776', 'c'),
#   ('PMC7282155', 't')},
#  'photographs': {('PMC4779090', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7282159', 'c')},
#  'demonstrate': {('PMC4706274', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'change': {('PMC4706276', 'c'),
#   ('PMC4706289', 't'),
#   ('PMC4706292', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7583549', 'c')},
#  'fat': {('PMC7279776', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7282159', 't')},
#  'distribution': {('PMC4706275', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779103', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7282159', 'c')},
#  'initiation': {('PMC7279776', 'c'), ('PMC7282151', 't')},
#  'immunotherapy': {('PMC7279776', 'c')},
#  'central': {('PMC4706284', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7282159', 'c')},
#  'obesity': {('PMC7279776', 'c')},
#  'decreased': {('PMC4706274', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7583549', 'c')},
#  'adipose': {('PMC7279776', 'c'), ('PMC7282159', 'c')},
#  'extremities': {('PMC7279776', 'c'), ('PMC7282159', 'c')},
#  'weight': {('PMC4706276', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779094', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7279776', 'c')},
#  'triglyceride': {('PMC7279776', 'c')},
#  'insulin': {('PMC4779090', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7282150', 'c'),
#   ('PMC7282150', 't'),
#   ('PMC7282159', 'c')},
#  'requirements': {('PMC4706274', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7279776', 'c')},
#  'recurrent': {('PMC7279768', 't'), ('PMC7282154', 't'), ('PMC7282158', 'c')},
#  'painful': {('PMC7279768', 't')},
#  'hashimoto': {('PMC7279768', 'c'), ('PMC7279768', 't')},
#  'thyroiditis': {('PMC7279768', 'c'), ('PMC7279768', 't')},
#  'successfully': {('PMC4779111', 'c'), ('PMC7279768', 't')},
#  'thyroidectomy': {('PMC7279768', 't'),
#   ('PMC7279771', 't'),
#   ('PMC7282155', 't')},
#  'ultrasound': {('PMC7279768', 'c'),
#   ('PMC7279774', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282158', 'c')},
#  'thyroid': {('PMC7279768', 'c'),
#   ('PMC7279774', 'c'),
#   ('PMC7282152', 'c'),
#   ('PMC7282155', 't'),
#   ('PMC7282158', 'c'),
#   ('PMC7282158', 't')},
#  'gland': {('PMC7279768', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7279774', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282157', 'c'),
#   ('PMC7282159', 'c')},
#  'left': {('PMC4706275', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7279774', 'c'),
#   ('PMC7279775', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7583549', 'c')},
#  'lobes': {('PMC7279768', 'c')},
#  'showed': {('PMC4779111', 'c'), ('PMC7279768', 'c')},
#  'heterogeneous': {('PMC4779111', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7279773', 'c')},
#  'echogenicity': {('PMC7279768', 'c')},
#  'evidence': {('PMC4706279', 't'),
#   ('PMC4779099', 't'),
#   ('PMC7279768', 'c'),
#   ('PMC7282157', 'c')},
#  'discrete': {('PMC7279768', 'c')},
#  'nodules': {('PMC7279768', 'c')},
#  'graphic': {('PMC7279776', 'c')},
#  'representation': {('PMC4706283', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706286', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7282150', 'c')},
#  'diagnostic': {('PMC4706275', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7583549', 'c')},
#  'workup': {('PMC7279776', 'c')},
#  'acute': {('PMC7279776', 'c'), ('PMC7583549', 'c')},
#  'patients': {('PMC4706277', 'c'),
#   ('PMC4706277', 't'),
#   ('PMC4706281', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706288', 't'),
#   ('PMC7279771', 't'),
#   ('PMC7279776', 'c'),
#   ('PMC7583549', 'c')},
#  'therapy': {('PMC7279776', 'c'),
#   ('PMC7282150', 'c'),
#   ('PMC7282151', 't'),
#   ('PMC7282158', 'c')},
#  'abs': {('PMC4706292', 'c'), ('PMC7279776', 'c')},
#  'antibodies': {('PMC4706281', 't'), ('PMC4779091', 'c'), ('PMC7279776', 'c')},
#  'agl': {('PMC7279776', 'c')},
#  'ana': {('PMC7279776', 'c')},
#  'antinuclear': {('PMC7279776', 'c')},
#  'antibody': {('PMC4706273', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779100', 't'),
#   ('PMC7279776', 'c')},
#  'anti': {('PMC4706273', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779112', 't'),
#   ('PMC7279776', 'c'),
#   ('PMC7282150', 't')},
#  'dsdna': {('PMC7279776', 'c')},
#  'double': {('PMC7279776', 'c')},
#  'stranded': {('PMC7279776', 'c')},
#  'deoxyribonucleic': {('PMC7279776', 'c')},
#  'acid': {('PMC4706278', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7583549', 'c')},
#  'fbg': {('PMC7279776', 'c')},
#  'fast': {('PMC7279776', 'c'), ('PMC7282148', 'c')},
#  'blood': {('PMC4706293', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779096', 't'),
#   ('PMC7279776', 'c'),
#   ('PMC7282159', 'c')},
#  'glucose': {('PMC4779090', 'c'), ('PMC7279776', 'c')},
#  'hiv': {('PMC7279776', 'c')},
#  'human': {('PMC4706278', 'c'),
#   ('PMC4706278', 't'),
#   ('PMC4706281', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779094', 't'),
#   ('PMC4779098', 'c'),
#   ('PMC4779098', 't'),
#   ('PMC4779111', 't'),
#   ('PMC7279776', 'c'),
#   ('PMC7583549', 'c')},
#  'immunodeficiency': {('PMC7279776', 'c')},
#  'virus': {('PMC4706288', 't'), ('PMC7279776', 'c'), ('PMC7282150', 'c')},
#  'antiprogrammed': {('PMC7279776', 'c')},
#  'cell': {('PMC4706278', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4779103', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC4779111', 't'),
#   ('PMC4779112', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7279776', 'c'),
#   ('PMC7282148', 't'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'death': {('PMC7279775', 't'), ('PMC7279776', 'c')},
#  'receptor': {('PMC7279776', 'c'), ('PMC7282152', 'c'), ('PMC7282159', 'c')},
#  'spep': {('PMC7279776', 'c')},
#  'protein': {('PMC4779105', 'c'),
#   ('PMC4779105', 't'),
#   ('PMC7279776', 'c'),
#   ('PMC7282159', 'c')},
#  'electrophoresis': {('PMC7279776', 'c')},
#  'histopathology': {('PMC7279768', 'c')},
#  'hematoxylin': {('PMC4706291', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7282159', 'c')},
#  'eosin': {('PMC4706291', 'c'), ('PMC7279768', 'c'), ('PMC7282159', 'c')},
#  'stain': {('PMC4706291', 'c'), ('PMC7279768', 'c'), ('PMC7282159', 'c')},
#  'igg': {('PMC4706273', 'c'), ('PMC4706281', 'c'), ('PMC7279768', 'c')},
#  'immunohistochemical': {('PMC4706291', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7282159', 'c')},
#  'low': {('PMC4706281', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7583549', 'c')},
#  'power': {('PMC4779113', 'c'), ('PMC7279768', 'c')},
#  'view': {('PMC7279768', 'c'), ('PMC7282159', 'c')},
#  'recognizable': {('PMC7279768', 'c')},
#  'germinal': {('PMC7279768', 'c')},
#  'centers': {('PMC7279768', 'c')},
#  'moderate': {('PMC7279768', 'c')},
#  'fibrosis': {('PMC7279768', 'c'), ('PMC7282159', 'c')},
#  'high': {('PMC4706287', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'group': {('PMC4706273', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279768', 'c')},
#  'entrapped': {('PMC7279768', 'c')},
#  'follicles': {('PMC7279768', 'c')},
#  'marked': {('PMC7279768', 'c'), ('PMC7282158', 'c')},
#  'lymphocytic': {('PMC7279768', 'c')},
#  'plasmacytic': {('PMC7279768', 'c')},
#  'infiltrate': {('PMC7279768', 'c'), ('PMC7282159', 'c')},
#  'panels': {('PMC4706275', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279768', 'c')},
#  'show': {('PMC4706275', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'area': {('PMC4706275', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC7279768', 'c')},
#  'stained': {('PMC4779090', 'c'), ('PMC7279768', 'c'), ('PMC7282159', 'c')},
#  'immunohistochemistry': {('PMC7279768', 'c')},
#  'revealing': {('PMC7279768', 'c')},
#  'many': {('PMC7279768', 'c'), ('PMC7282159', 'c')},
#  'interspersed': {('PMC7279768', 'c')},
#  'positive': {('PMC4706281', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7279768', 'c'),
#   ('PMC7282159', 'c')},
#  'hypothyroidism': {('PMC7279774', 't'),
#   ('PMC7279775', 't'),
#   ('PMC7282159', 'c')},
#  'goiter': {('PMC7279774', 't')},
#  'young': {('PMC4706285', 't'), ('PMC7279774', 't'), ('PMC7583548', 'c')},
#  'male': {('PMC4779099', 'c'), ('PMC7279774', 't')},
#  'suspected': {('PMC7279774', 't')},
#  'dietary': {('PMC7279774', 't')},
#  'iodine': {('PMC7279774', 'c'), ('PMC7279774', 't')},
#  'deficiency': {('PMC7279774', 't'), ('PMC7282159', 'c')},
#  'followed': {('PMC4706292', 'c'), ('PMC7279774', 't')},
#  'thyrotoxicosis': {('PMC7279771', 't'),
#   ('PMC7279774', 't'),
#   ('PMC7282155', 't')},
#  'supplementation': {('PMC7279774', 't')},
#  'enlarged': {('PMC7279774', 'c'), ('PMC7282159', 'c')},
#  'measuring': {('PMC7279773', 'c'), ('PMC7279774', 'c')},
#  'widest': {('PMC7279774', 'c')},
#  'therapeutic': {('PMC4779091', 't'),
#   ('PMC4779100', 't'),
#   ('PMC4779113', 'c'),
#   ('PMC7279771', 'c'),
#   ('PMC7279771', 't')},
#  'exchange': {('PMC7279771', 'c'), ('PMC7279771', 't')},
#  'bridge': {('PMC4779096', 'c'), ('PMC7279771', 't')},
#  'total': {('PMC4706276', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7279771', 't'),
#   ('PMC7282155', 't'),
#   ('PMC7282159', 'c'),
#   ('PMC7583548', 'c'),
#   ('PMC7583549', 'c')},
#  'severe': {('PMC7279771', 't')},
#  'measured': {('PMC4706283', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779103', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7279771', 'c'),
#   ('PMC7282148', 'c')},
#  'free': {('PMC4706280', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7279771', 'c'),
#   ('PMC7583549', 'c')},
#  'tpe': {('PMC7279771', 'c')},
#  'thyroxine': {('PMC7279771', 'c')},
#  'radioactive': {('PMC7279774', 'c')},
#  'uptake': {('PMC4706291', 'c'), ('PMC4779111', 'c'), ('PMC7279774', 'c')},
#  'diffusely': {('PMC7279774', 'c'), ('PMC7282148', 'c')},
#  'increased': {('PMC4779111', 'c'), ('PMC7279774', 'c'), ('PMC7583549', 'c')},
#  'hours': {('PMC7279774', 'c')},
#  'spontaneous': {('PMC7279773', 't'), ('PMC7282151', 't')},
#  'resolution': {('PMC7279773', 't')},
#  'primary': {('PMC7279773', 't'), ('PMC7282154', 't')},
#  'hypercortisolism': {('PMC7279773', 't')},
#  'cushing': {('PMC7279773', 't')},
#  'disease': {('PMC7279773', 't'),
#   ('PMC7282148', 't'),
#   ('PMC7282154', 'c'),
#   ('PMC7282159', 'c')},
#  'pituitary': {('PMC7279773', 'c'), ('PMC7279773', 't')},
#  'hemorrhage': {('PMC7279773', 'c'),
#   ('PMC7279773', 't'),
#   ('PMC7282157', 'c'),
#   ('PMC7282157', 't')},
#  'mri': {('PMC7279773', 'c'), ('PMC7282148', 'c')},
#  'initial': {('PMC4706273', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC7279773', 'c')},
#  'presentation': {('PMC7279773', 'c'), ('PMC7282159', 'c')},
#  'indeterminate': {('PMC7279773', 'c')},
#  'sellar': {('PMC7279773', 'c')},
#  'suprasellar': {('PMC7279773', 'c')},
#  'mass': {('PMC4706276', 't'),
#   ('PMC7279773', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282151', 'c'),
#   ('PMC7282154', 'c'),
#   ('PMC7282155', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7282159', 'c')},
#  'coronal': {('PMC7279773', 'c'), ('PMC7282151', 'c'), ('PMC7282159', 'c')},
#  'section': {('PMC4706287', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7282151', 'c'),
#   ('PMC7282154', 'c')},
#  'without': {('PMC4706273', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7282157', 'c')},
#  'contrast': {('PMC7279773', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282151', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7282159', 'c')},
#  'sagittal': {('PMC7279773', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282151', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7282159', 'c')},
#  'demonstrating': {('PMC7279773', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282154', 'c'),
#   ('PMC7282159', 'c')},
#  'lack': {('PMC4706292', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7282159', 'c')},
#  'enhancement': {('PMC7279773', 'c'), ('PMC7282159', 'c')},
#  'extension': {('PMC7279773', 'c')},
#  'optic': {('PMC7279773', 'c'), ('PMC7282151', 'c')},
#  'chiasm': {('PMC7279773', 'c'), ('PMC7282151', 'c')},
#  'original': {('PMC4706284', 'c'), ('PMC4706293', 'c'), ('PMC7279773', 'c')},
#  'differential': {('PMC7279773', 'c'), ('PMC7282159', 'c')},
#  'diagnosis': {('PMC7279773', 'c'), ('PMC7282159', 'c'), ('PMC7282159', 't')},
#  'per': {('PMC4706284', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC7279773', 'c')},
#  'neuroradiology': {('PMC7279773', 'c')},
#  'atypical': {('PMC7279773', 'c')},
#  'macroadenoma': {('PMC7279773', 'c')},
#  'less': {('PMC4706274', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC7279773', 'c')},
#  'likely': {('PMC7279773', 'c')},
#  'craniopharyngioma': {('PMC7279773', 'c')},
#  'germ': {('PMC7279773', 'c')},
#  'tumor': {('PMC4706273', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4779105', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779108', 't'),
#   ('PMC7279773', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282154', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7583549', 'c')},
#  'metastasis': {('PMC7279773', 'c')},
#  'magnetic': {('PMC7279773', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282151', 'c'),
#   ('PMC7282159', 'c')},
#  'resonance': {('PMC7279773', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282151', 'c'),
#   ('PMC7282159', 'c')},
#  'imaging': {('PMC4706291', 'c'), ('PMC7279773', 'c'), ('PMC7282159', 'c')},
#  'follow': {('PMC7279773', 'c'), ('PMC7282150', 'c'), ('PMC7282157', 'c')},
#  'interval': {('PMC4706275', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779108', 't'),
#   ('PMC4779110', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7282157', 'c'),
#   ('PMC7583549', 'c')},
#  'decrease': {('PMC7279773', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282150', 'c'),
#   ('PMC7282157', 'c'),
#   ('PMC7282159', 'c')},
#  'size': {('PMC4706293', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282157', 'c'),
#   ('PMC7282159', 'c')},
#  'lesion': {('PMC7279773', 'c')},
#  'retrospectively': {('PMC7279773', 'c')},
#  'suggestive': {('PMC7279773', 'c')},
#  'resorption': {('PMC7279773', 'c')},
#  'secondary': {('PMC7279773', 'c'), ('PMC7282157', 't')},
#  'underlying': {('PMC7279773', 'c'), ('PMC7282157', 'c')},
#  'adenoma': {('PMC7279773', 'c')},
#  'months': {('PMC4706284', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7279775', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7282159', 'c')},
#  'hypoenhancing': {('PMC7279773', 'c')},
#  'region': {('PMC4706281', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282159', 'c')},
#  'noted': {('PMC7279773', 'c'), ('PMC7282159', 'c')},
#  'scalloping': {('PMC7279773', 'c')},
#  'sphenoid': {('PMC7279773', 'c')},
#  'bone': {('PMC7279773', 'c'), ('PMC7282159', 'c')},
#  'residual': {('PMC4779108', 'c'), ('PMC7279773', 'c')},
#  'diameter': {('PMC4706291', 'c'), ('PMC7279773', 'c')},
#  'effect': {('PMC4706274', 'c'),
#   ('PMC4706275', 'c'),
#   ('PMC4706275', 't'),
#   ('PMC4706277', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706280', 't'),
#   ('PMC4706285', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779090', 't'),
#   ('PMC4779104', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779112', 't'),
#   ('PMC4779113', 'c'),
#   ('PMC7279773', 'c'),
#   ('PMC7583548', 'c'),
#   ('PMC7583549', 'c')},
#  'recent': {('PMC7279773', 'c')},
#  'overall': {('PMC4706274', 'c'), ('PMC4779106', 'c'), ('PMC7279773', 'c')},
#  'continued': {('PMC7279773', 'c')},
#  'mild': {('PMC7279773', 'c'), ('PMC7282148', 'c')},
#  'improvement': {('PMC4779108', 't'), ('PMC7279773', 'c')},
#  'concavity': {('PMC7279773', 'c')},
#  'superior': {('PMC7279773', 'c')},
#  'surface': {('PMC4706287', 'c'),
#   ('PMC4779103', 'c'),
#   ('PMC4779103', 't'),
#   ('PMC7279773', 'c')},
#  'additionally': {('PMC7279773', 'c'), ('PMC7282159', 'c')},
#  'minimally': {('PMC7279773', 'c')},
#  'improved': {('PMC4779090', 'c'), ('PMC7279773', 'c')},
#  'focus': {('PMC7279773', 'c')},
#  'delayed': {('PMC4706292', 'c'), ('PMC7279773', 'c'), ('PMC7583549', 'c')},
#  'within': {('PMC4706274', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7279773', 'c')},
#  'reflecting': {('PMC7279773', 'c')},
#  'microadenoma': {('PMC7279773', 'c')},
#  'xrcc': {('PMC7279775', 't')},
#  'mutations': {('PMC7279775', 't'), ('PMC7282159', 'c')},
#  'infant': {('PMC4706276', 'c'), ('PMC7279775', 't')},
#  'microcephalic': {('PMC7279775', 't')},
#  'primordial': {('PMC7279775', 't')},
#  'dwarfism': {('PMC7279775', 't')},
#  'dilated': {('PMC7279775', 't')},
#  'cardiomyopathy': {('PMC7279775', 't')},
#  'subclinical': {('PMC7279775', 't')},
#  'early': {('PMC4779098', 'c'), ('PMC7279775', 't')},
#  'expanding': {('PMC7279775', 't')},
#  'phenotype': {('PMC7279775', 't')},
#  'atrial': {('PMC7279775', 'c')},
#  'ventricular': {('PMC7279775', 'c'), ('PMC7282159', 'c')},
#  'dilation': {('PMC7279775', 'c')},
#  'echocardiogram': {('PMC7279775', 'c')},
#  'life': {('PMC4706276', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706279', 't'),
#   ('PMC4706292', 'c'),
#   ('PMC7279775', 'c'),
#   ('PMC7583549', 'c')},
#  'familial': {('PMC7282152', 't')},
#  'nonautoimmune': {('PMC7282152', 'c'), ('PMC7282152', 't')},
#  'hyperthyroidism': {('PMC7282152', 'c'), ('PMC7282152', 't')},
#  'pregnancy': {('PMC7282152', 't')},
#  'family': {('PMC7282152', 'c')},
#  'tree': {('PMC4706292', 'c'), ('PMC4779096', 'c'), ('PMC7282152', 'c')},
#  'mother': {('PMC4779100', 'c'), ('PMC7282152', 'c')},
#  'diagnosed': {('PMC4706281', 'c'), ('PMC7282152', 'c')},
#  'tshr': {('PMC7282152', 'c')},
#  'activating': {('PMC7282152', 'c')},
#  'germline': {('PMC7282152', 'c')},
#  'mutation': {('PMC7282152', 'c'), ('PMC7282159', 'c')},
#  'brother': {('PMC7282152', 'c')},
#  'twin': {('PMC7282152', 'c')},
#  'sister': {('PMC7282152', 'c')},
#  'proband': {('PMC7282152', 'c')},
#  'stimulating': {('PMC7282152', 'c'), ('PMC7583549', 'c')},
#  'amiodarone': {('PMC7282155', 't')},
#  'follicular': {('PMC7282155', 't'), ('PMC7282159', 'c')},
#  'cancer': {('PMC4706291', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779112', 't'),
#   ('PMC7282155', 't')},
#  'ray': {('PMC4706291', 'c'), ('PMC7282155', 'c'), ('PMC7282159', 'c')},
#  'large': {('PMC4706291', 'c'),
#   ('PMC4779105', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282155', 'c'),
#   ('PMC7583549', 'c')},
#  'opacity': {('PMC7282155', 'c')},
#  'projected': {('PMC7282155', 'c')},
#  'thorax': {('PMC7282155', 'c'), ('PMC7282159', 'c')},
#  'destructs': {('PMC7282155', 'c')},
#  'lateral': {('PMC7282155', 'c'), ('PMC7282158', 'c')},
#  'fifth': {('PMC7282155', 'c')},
#  'rib': {('PMC7282155', 'c')},
#  'keeping': {('PMC7282155', 'c')},
#  'chest': {('PMC7282155', 'c')},
#  'wall': {('PMC7282155', 'c')},
#  'pharma': {('PMC4706289', 't')},
#  'success': {('PMC4706289', 't')},
#  'product': {('PMC4706289', 'c'),
#   ('PMC4706289', 't'),
#   ('PMC4779098', 'c'),
#   ('PMC4779102', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779106', 't')},
#  'development': {('PMC4706274', 't'),
#   ('PMC4706289', 't'),
#   ('PMC4779096', 't'),
#   ('PMC4779102', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779112', 't')},
#  'biotechnology': {('PMC4706289', 't')},
#  'paradigm': {('PMC4706289', 't'), ('PMC4779106', 'c')},
#  'attrition': {('PMC4706289', 't')},
#  'biotech': {('PMC4706289', 'c')},
#  'approvals': {('PMC4706289', 'c')},
#  'fda': {('PMC4706289', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779106', 't'),
#   ('PMC4779113', 'c')},
#  'new': {('PMC4706284', 'c'), ('PMC4706289', 'c'), ('PMC7583549', 'c')},
#  'products': {('PMC4706284', 't'),
#   ('PMC4706289', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC4779104', 't'),
#   ('PMC4779106', 'c'),
#   ('PMC4779113', 'c')},
#  'added': {('PMC4706281', 'c'), ('PMC4706289', 'c')},
#  'uses': {('PMC4706289', 'c')},
#  '1980': {('PMC4706289', 'c')},
#  '2014': {('PMC4706289', 'c')},
#  'nme': {('PMC4706289', 'c')},
#  'nbe': {('PMC4706289', 'c')},
#  '1990': {('PMC4706289', 'c')},
#  'innovation': {('PMC4706289', 'c')},
#  'nbes': {('PMC4706289', 'c')},
#  'nmes': {('PMC4706289', 'c')},
#  '1986': {('PMC4706289', 'c')},
#  'injectable': {('PMC4706273', 't')},
#  'pentablock': {('PMC4706273', 'c'), ('PMC4706273', 't')},
#  'copolymer': {('PMC4706273', 'c'), ('PMC4706273', 't'), ('PMC4779114', 't')},
#  'based': {('PMC4706273', 't'),
#   ('PMC4706275', 'c'),
#   ('PMC4706276', 't'),
#   ('PMC4706278', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706279', 't'),
#   ('PMC4706283', 'c'),
#   ('PMC4706283', 't'),
#   ('PMC4706287', 't'),
#   ('PMC4706293', 't'),
#   ('PMC4779091', 'c'),
#   ('PMC4779102', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC7583548', 't')},
#  'thermoresponsive': {('PMC4706273', 't')},
#  'hydrogels': {('PMC4706273', 'c'), ('PMC4706273', 't'), ('PMC4706291', 'c')},
#  'sustained': {('PMC4706273', 't')},
#  'release': {('PMC4706273', 'c'),
#   ('PMC4706273', 't'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779102', 'c'),
#   ('PMC4779102', 't'),
#   ('PMC7583549', 'c')},
#  'vaccines': {('PMC4706273', 't')},
#  'sol': {('PMC4706273', 'c'), ('PMC4779109', 'c')},
#  'gel': {('PMC4706273', 'c'), ('PMC4706291', 'c'), ('PMC4779102', 'c')},
#  'transition': {('PMC4706273', 'c'), ('PMC4779112', 'c')},
#  'temperature': {('PMC4706273', 'c')},
#  'copolymers': {('PMC4706273', 'c')},
#  'presence': {('PMC4706273', 'c'),
#   ('PMC4779099', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7282148', 'c')},
#  'absence': {('PMC4706273', 'c'), ('PMC4706284', 'c'), ('PMC4779111', 'c')},
#  'plga': {('PMC4706273', 'c')},
#  'loaded': {('PMC4706273', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706291', 't')},
#  'ova': {('PMC4706273', 'c')},
#  'mpl': {('PMC4706273', 'c')},
#  'vitro': {('PMC4706273', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4779098', 't'),
#   ('PMC4779099', 't'),
#   ('PMC4779102', 'c'),
#   ('PMC4779102', 't'),
#   ('PMC4779109', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC4779114', 't'),
#   ('PMC7583548', 'c')},
#  'stability': {('PMC4706273', 'c')},
#  'modified': {('PMC4706273', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4779103', 'c'),
#   ('PMC4779112', 'c')},
#  'triblock': {('PMC4706273', 'c')},
#  'pbs': {('PMC4706273', 'c'), ('PMC4706291', 'c')},
#  'buffer': {('PMC4706273', 'c'), ('PMC4706287', 'c'), ('PMC4779101', 'c')},
#  'values': {('PMC4706273', 'c'),
#   ('PMC4706275', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7583548', 'c')},
#  'shown': {('PMC4706273', 'c'),
#   ('PMC4706274', 'c'),
#   ('PMC4706276', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779105', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7583549', 'c')},
#  'mean': {('PMC4706273', 'c'),
#   ('PMC4706274', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779099', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7583548', 'c'),
#   ('PMC7583549', 'c')},
#  'profiles': {('PMC4706273', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779098', 'c'),
#   ('PMC4779099', 'c'),
#   ('PMC4779101', 'c'),
#   ('PMC4779102', 'c'),
#   ('PMC4779103', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779114', 'c')},
#  'fitc': {('PMC4706273', 'c')},
#  'data': {('PMC4706273', 'c'),
#   ('PMC4706274', 'c'),
#   ('PMC4706276', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706292', 't'),
#   ('PMC4706293', 'c'),
#   ('PMC4706293', 't'),
#   ('PMC4779091', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779099', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7583548', 'c'),
#   ('PMC7583549', 'c'),
#   ('PMC7583549', 't')},
#  'expansion': {('PMC4706273', 'c')},
#  'specific': {('PMC4706273', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706278', 't'),
#   ('PMC4706281', 'c'),
#   ('PMC7282159', 'c')},
#  'cd8': {('PMC4706273', 'c')},
#  'cd4': {('PMC4706273', 'c')},
#  'transgenic': {('PMC4706273', 'c')},
#  'lymph': {('PMC4706273', 'c'),
#   ('PMC7282154', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7282159', 'c')},
#  'nodes': {('PMC4706273', 'c'), ('PMC7282158', 'c'), ('PMC7282159', 'c')},
#  'days': {('PMC4706273', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4706284', 't'),
#   ('PMC4706287', 'c'),
#   ('PMC7583549', 'c')},
#  'post': {('PMC4706273', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779094', 'c'),
#   ('PMC4779105', 'c'),
#   ('PMC7282151', 'c'),
#   ('PMC7282157', 'c'),
#   ('PMC7282158', 'c')},
#  'immunization': {('PMC4706273', 'c')},
#  'alum': {('PMC4706273', 'c')},
#  'presented': {('PMC4706273', 'c'), ('PMC4706279', 'c')},
#  'individual': {('PMC4706273', 'c'),
#   ('PMC4706274', 'c'),
#   ('PMC4706275', 'c'),
#   ('PMC4706276', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7583549', 'c')},
#  'mice': {('PMC4706273', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706283', 't'),
#   ('PMC4706291', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779090', 't'),
#   ('PMC4779100', 'c'),
#   ('PMC4779100', 't'),
#   ('PMC4779112', 'c'),
#   ('PMC7583548', 'c'),
#   ('PMC7583549', 'c')},
#  'titres': {('PMC4706273', 'c')},
#  'prophylactic': {('PMC4706273', 'c')},
#  'response': {('PMC4706273', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC7583549', 'c')},
#  'survival': {('PMC4706273', 'c')},
#  'analysis': {('PMC4706273', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706279', 't'),
#   ('PMC4706284', 'c'),
#   ('PMC4706288', 't'),
#   ('PMC4706292', 'c'),
#   ('PMC4706292', 't'),
#   ('PMC4706293', 'c'),
#   ('PMC4706293', 't'),
#   ('PMC4779090', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7583549', 'c'),
#   ('PMC7583549', 't')},
#  'injected': {('PMC4706273', 'c'), ('PMC4706291', 'c')},
#  'subcutaneously': {('PMC4706273', 'c')},
#  '105': {('PMC4706273', 'c')},
#  'b16': {('PMC4706273', 'c'), ('PMC4706291', 'c')},
#  'blank': {('PMC4706273', 'c')},
#  'vaccine': {('PMC4706273', 'c')},
#  'soluble': {('PMC4706273', 'c')},
#  'unimmunized': {('PMC4706273', 'c')},
#  'control': {('PMC4706273', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'surviving': {('PMC4706273', 'c'), ('PMC4706291', 'c')},
#  'rechallenged': {('PMC4706273', 'c')},
#  'challenge': {('PMC4706273', 'c')},
#  'opposite': {('PMC4706273', 'c')},
#  'flank': {('PMC4706273', 'c')},
#  'insufficiency': {('PMC7282154', 't'), ('PMC7282157', 't')},
#  'antiphospholipid': {('PMC7282157', 't')},
#  'angiography': {('PMC7282157', 'c')},
#  'pulmonary': {('PMC7282157', 'c')},
#  'embolism': {('PMC7282157', 'c')},
#  'abdominal': {('PMC7282157', 'c')},
#  'concerning': {('PMC7282157', 'c')},
#  'hematomas': {('PMC7282157', 'c')},
#  'significant': {('PMC4706274', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC7282157', 'c'),
#   ('PMC7583548', 'c')},
#  'favored': {('PMC7282157', 'c')},
#  'represent': {('PMC4706274', 'c'),
#   ('PMC4706275', 'c'),
#   ('PMC4706276', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7282157', 'c')},
#  'neoplasm': {('PMC7282157', 'c')},
#  'population': {('PMC4706275', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706288', 't'),
#   ('PMC4706293', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC4779112', 'c')},
#  'pharmacokinetics': {('PMC4706285', 't'),
#   ('PMC4706288', 't'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779091', 't'),
#   ('PMC4779099', 't')},
#  'paritaprevir': {('PMC4706288', 'c'), ('PMC4706288', 't')},
#  'ombitasvir': {('PMC4706288', 'c'), ('PMC4706288', 't')},
#  'dasabuvir': {('PMC4706288', 'c'), ('PMC4706288', 't')},
#  'ritonavir': {('PMC4706288', 'c'),
#   ('PMC4706288', 't'),
#   ('PMC4779112', 'c'),
#   ('PMC4779112', 't')},
#  'ribavirin': {('PMC4706288', 'c'), ('PMC4706288', 't')},
#  'hepatitis': {('PMC4706288', 't'), ('PMC7282150', 'c')},
#  'genotype': {('PMC4706288', 't')},
#  'infection': {('PMC4706288', 't')},
#  'combined': {('PMC4706274', 'c'),
#   ('PMC4706288', 't'),
#   ('PMC4779112', 'c'),
#   ('PMC7583549', 'c')},
#  'phase': {('PMC4706280', 'c'),
#   ('PMC4706288', 't'),
#   ('PMC4706292', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC7282148', 'c')},
#  'studies': {('PMC4706278', 'c'),
#   ('PMC4706288', 't'),
#   ('PMC4706292', 'c'),
#   ('PMC4779100', 't'),
#   ('PMC4779113', 'c'),
#   ('PMC7583549', 'c')},
#  'related': {('PMC4706284', 'c'), ('PMC4706288', 'c'), ('PMC4706292', 'c')},
#  'relative': {('PMC4706278', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7583549', 'c')},
#  'bioavailability': {('PMC4706288', 'c'), ('PMC4706292', 'c')},
#  'spray': {('PMC4706287', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4779101', 't'),
#   ('PMC4779103', 'c')},
#  'dried': {('PMC4706287', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4779096', 't'),
#   ('PMC4779101', 't'),
#   ('PMC4779103', 'c')},
#  'dispersion': {('PMC4706288', 'c'), ('PMC4779101', 't')},
#  'tablet': {('PMC4706284', 'c'), ('PMC4706288', 'c')},
#  'hard': {('PMC4706288', 'c')},
#  'gelatin': {('PMC4706288', 'c')},
#  'capsule': {('PMC4706288', 'c')},
#  'formulations': {('PMC4706287', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4779103', 'c'),
#   ('PMC4779113', 'c')},
#  'pharmacokinetic': {('PMC4706279', 't'),
#   ('PMC4706283', 'c'),
#   ('PMC4706283', 't'),
#   ('PMC4706285', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 't'),
#   ('PMC4706293', 't'),
#   ('PMC4779096', 'c'),
#   ('PMC4779112', 'c')},
#  'evaluations': {('PMC4706288', 'c')},
#  'model': {('PMC4706275', 'c'),
#   ('PMC4706276', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706279', 't'),
#   ('PMC4706283', 'c'),
#   ('PMC4706283', 't'),
#   ('PMC4706285', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4706293', 't'),
#   ('PMC4779091', 'c'),
#   ('PMC4779091', 't'),
#   ('PMC4779094', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779110', 't'),
#   ('PMC4779111', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779112', 't'),
#   ('PMC7583549', 'c')},
#  'derived': {('PMC4706279', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779111', 'c')},
#  'estimates': {('PMC4706288', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7583549', 'c')},
#  'steady': {('PMC4706279', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC7583549', 'c')},
#  'state': {('PMC4706279', 'c'),
#   ('PMC4706287', 't'),
#   ('PMC4706288', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'maximum': {('PMC4706285', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7583549', 'c')},
#  'concentration': {('PMC4706280', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7583549', 'c')},
#  'curve': {('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7583549', 'c')},
#  'covariates': {('PMC4706288', 'c')},
#  'identified': {('PMC4706284', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC7282159', 'c')},
#  'significantly': {('PMC4706288', 'c'), ('PMC4779111', 'c')},
#  'apparent': {('PMC4706274', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC7282148', 'c')},
#  'clearance': {('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC4779112', 'c')},
#  'parameters': {('PMC4706277', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7583549', 'c')},
#  'ratio': {('PMC4706281', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7282159', 'c')},
#  'indicates': {('PMC4706274', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC7583549', 'c')},
#  'similar': {('PMC4706288', 'c'), ('PMC4706292', 'c'), ('PMC4779102', 'c')},
#  'subgroup': {('PMC4706288', 'c')},
#  'analyzed': {('PMC4706281', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC7583549', 'c')},
#  'rest': {('PMC4706288', 'c')},
#  'error': {('PMC4706279', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779108', 'c')},
#  'bars': {('PMC4706288', 'c'), ('PMC7583549', 'c')},
#  'confidence': {('PMC4706288', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779112', 'c')},
#  'intervals': {('PMC4706288', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779112', 'c')},
#  'groups': {('PMC4706288', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7583549', 'c')},
#  'analyses': {('PMC4706288', 'c'), ('PMC7583549', 'c')},
#  'stratified': {('PMC4706277', 'c'), ('PMC4706288', 'c'), ('PMC4779104', 'c')},
#  'age': {('PMC4706275', 'c'),
#   ('PMC4706275', 't'),
#   ('PMC4706288', 'c'),
#   ('PMC4779094', 'c'),
#   ('PMC7282159', 'c')},
#  'plotted': {('PMC4706274', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779094', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7583549', 'c')},
#  'years': {('PMC4706288', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779094', 'c'),
#   ('PMC7282159', 'c')},
#  'creatinine': {('PMC4706288', 'c')},
#  '120': {('PMC4706288', 'c'), ('PMC4706292', 'c'), ('PMC4779102', 'c')},
#  'min': {('PMC4706280', 'c'),
#   ('PMC4706284', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779094', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7583549', 'c')},
#  'bwt': {('PMC4706288', 'c')},
#  'cyp': {('PMC4706278', 'c'), ('PMC4706288', 'c'), ('PMC4779112', 'c')},
#  '2c8': {('PMC4706288', 'c')},
#  'cytochrome': {('PMC4706278', 't'), ('PMC4706288', 'c')},
#  'p450': {('PMC4706278', 'c'), ('PMC4706278', 't'), ('PMC4706288', 'c')},
#  'visual': {('PMC4706275', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779112', 'c')},
#  'predictive': {('PMC4706275', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706288', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779094', 't'),
#   ('PMC4779100', 'c'),
# ...
#   ('PMC4779091', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7583549', 'c')},
#  'scales': {('PMC4706285', 'c'), ('PMC4706293', 'c'), ('PMC4779112', 'c')},
#  'evaluation': {('PMC4706281', 't'),
#   ('PMC4706293', 'c'),
#   ('PMC4779094', 't'),
#   ('PMC4779101', 't'),
#   ('PMC4779113', 't'),
#   ('PMC7583548', 't')},
#  'scaled': {('PMC4706276', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC4779113', 't')},
#  'predict': {('PMC4706293', 'c'), ('PMC4779091', 't')},
#  'oral': {('PMC4706280', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706287', 't'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779099', 'c'),
#   ('PMC4779102', 't'),
#   ('PMC4779109', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7583548', 'c'),
#   ('PMC7583549', 'c')},
#  'children': {('PMC4706285', 'c'), ('PMC4706285', 't'), ('PMC4706293', 'c')},
#  '50th': {('PMC4706275', 'c'), ('PMC4706293', 'c'), ('PMC4779110', 'c')},
#  'wendling': {('PMC4706293', 'c')},
#  'dotted': {('PMC4706275', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779091', 'c')},
#  'quantification': {('PMC4706293', 'c')},
#  'assay': {('PMC4706274', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706293', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7282159', 'c')},
#  'platelet': {('PMC4706277', 'c'), ('PMC4706277', 't')},
#  'dynamics': {('PMC4706277', 'c'), ('PMC4706277', 't')},
#  'peritoneal': {('PMC4706277', 't')},
#  'carcinomatosis': {('PMC4706277', 't')},
#  'cytoreductive': {('PMC4706277', 't')},
#  'surgery': {('PMC4706277', 'c'),
#   ('PMC4706277', 't'),
#   ('PMC4706285', 'c'),
#   ('PMC4706285', 't'),
#   ('PMC7282158', 'c')},
#  'hyperthermic': {('PMC4706277', 't')},
#  'intraperitoneal': {('PMC4706277', 't'),
#   ('PMC4779090', 'c'),
#   ('PMC7282159', 'c')},
#  'oxaliplatin': {('PMC4706277', 'c'), ('PMC4706277', 't')},
#  'goodness': {('PMC4706277', 'c'), ('PMC4706285', 'c'), ('PMC4779112', 'c')},
#  'fit': {('PMC4706274', 't'),
#   ('PMC4706276', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779094', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7583549', 'c')},
#  'corrected': {('PMC4706277', 'c')},
#  'course': {('PMC4706275', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC7583549', 'c')},
#  'counts': {('PMC4706277', 'c'), ('PMC7583549', 'c')},
#  'corresponding': {('PMC4706277', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7282148', 'c')},
#  'non': {('PMC4706274', 'c'),
#   ('PMC4706277', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7282159', 'c')},
#  'splenectomized': {('PMC4706277', 'c')},
#  'cohort': {('PMC4706277', 'c')},
#  'spmax': {('PMC4706277', 'c')},
#  'peritoneum': {('PMC4706277', 'c')},
#  'duration': {('PMC4706277', 'c'), ('PMC4706292', 'c')},
#  'carrier': {('PMC4706277', 'c'), ('PMC4706287', 'c')},
#  'solution': {('PMC4706277', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4779109', 'c')},
#  'hio': {('PMC4706277', 'c')},
#  'diluted': {('PMC4706274', 'c'), ('PMC4706277', 'c')},
#  'icodextrin': {('PMC4706277', 'c')},
#  'dextrose': {('PMC4706277', 'c')},
#  'incidence': {('PMC4706277', 'c')},
#  'thrombocytopenia': {('PMC4706277', 'c')},
#  'thrombocytosis': {('PMC4706277', 'c')},
#  'gefitinib': {('PMC4706283', 'c'), ('PMC4706283', 't')},
#  'scale': {('PMC4706283', 't'),
#   ('PMC4706292', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC7583549', 'c')},
#  'humans': {('PMC4706283', 't')},
#  'mouse': {('PMC4706283', 'c'), ('PMC4779112', 'c'), ('PMC4779112', 't')},
#  'structure': {('PMC4706278', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7583549', 'c')},
#  'perfusion': {('PMC4706283', 'c')},
#  'rate': {('PMC4706276', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779094', 'c'),
#   ('PMC4779094', 't'),
#   ('PMC4779102', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779109', 't'),
#   ('PMC4779112', 'c'),
#   ('PMC7583549', 'c')},
#  'limited': {('PMC4706283', 'c'), ('PMC4706292', 'c')},
#  'kinetics': {('PMC4706275', 'c'), ('PMC4706283', 'c')},
#  'permeability': {('PMC4706283', 'c'), ('PMC7583548', 'c')},
#  'examined': {('PMC4706283', 'c')},
#  'tissues': {('PMC4706283', 'c')},
#  'following': {('PMC4706276', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC7583549', 'c')},
#  'intravenous': {('PMC4706283', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779099', 'c'),
#   ('PMC4779100', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'bolus': {('PMC4706283', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC7583549', 'c')},
#  'point': {('PMC4706283', 'c'), ('PMC4779099', 'c'), ('PMC4779104', 'c')},
#  'various': {('PMC4706283', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4779105', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'dot': {('PMC4706283', 'c')},
#  'vertical': {('PMC4706275', 'c'), ('PMC4706283', 'c'), ('PMC7583549', 'c')},
#  'bar': {('PMC4706283', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC7583549', 'c')},
#  'observations': {('PMC4706275', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779112', 'c')},
#  'proposed': {('PMC4706283', 'c'), ('PMC4779098', 'c'), ('PMC4779099', 'c')},
#  'different': {('PMC4706274', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706283', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779102', 'c'),
#   ('PMC4779103', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7583549', 'c')},
#  'dosing': {('PMC4706283', 'c'), ('PMC4706292', 'c'), ('PMC7583549', 'c')},
#  'regimens': {('PMC4706283', 'c')},
#  'healthy': {('PMC4706283', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779110', 't'),
#   ('PMC7282159', 'c')},
#  'tumors': {('PMC4706283', 'c'), ('PMC4779108', 't')},
#  'digitalized': {('PMC4706283', 'c')},
#  'published': {('PMC4706283', 'c'), ('PMC4779112', 'c')},
#  'articles': {('PMC4706283', 'c')},
#  'swaisland': {('PMC4706283', 'c')},
#  'nakagawa': {('PMC4706283', 'c')},
#  'simulations': {('PMC4706283', 'c'),
#   ('PMC4706286', 't'),
#   ('PMC4779091', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779113', 'c')},
#  'modeling': {('PMC4706275', 't'), ('PMC4779104', 'c'), ('PMC7583549', 'c')},
#  'testosterone': {('PMC4706275', 'c'), ('PMC4706275', 't')},
#  'circadian': {('PMC4706275', 't')},
#  'rhythm': {('PMC4706275', 't')},
#  'hypogonadal': {('PMC4706275', 'c'), ('PMC4706275', 't')},
#  'males': {('PMC4706275', 't')},
#  'circannual': {('PMC4706275', 't')},
#  'variations': {('PMC4706275', 't')},
#  'baseline': {('PMC4706275', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC7583549', 'c')},
#  'men': {('PMC4706275', 'c')},
#  'gray': {('PMC4706275', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC7583549', 'c')},
#  'smooth': {('PMC4706275', 'c')},
#  'regression': {('PMC4706275', 'c'),
#   ('PMC4706276', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779114', 'c')},
#  'interindividual': {('PMC4706275', 'c')},
#  'variability': {('PMC4706275', 'c'), ('PMC7583549', 'c')},
#  'base': {('PMC4706275', 'c'), ('PMC4779096', 'c')},
#  'season': {('PMC4706275', 'c')},
#  'including': {('PMC4706275', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC7282158', 'c'),
#   ('PMC7282159', 'c')},
#  'asterisks': {('PMC4706275', 'c')},
#  'outliers': {('PMC4706275', 'c')},
#  'correlation': {('PMC4706275', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706281', 't'),
#   ('PMC4779096', 'c'),
#   ('PMC4779109', 'c')},
#  'developed': {('PMC4706274', 'c'), ('PMC4706275', 'c'), ('PMC4779091', 'c')},
#  'characterize': {('PMC4706275', 'c')},
#  'scatterplots': {('PMC4706275', 'c')},
#  'middle': {('PMC4706275', 'c'), ('PMC4779109', 'c')},
#  'conditional': {('PMC4706275', 'c'), ('PMC4779112', 'c')},
#  'weighted': {('PMC4706275', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7282148', 'c'),
#   ('PMC7282159', 'c')},
#  'residuals': {('PMC4706275', 'c'), ('PMC4779110', 'c'), ('PMC4779112', 'c')},
#  'density': {('PMC4706275', 'c'), ('PMC4779105', 'c')},
#  'normalized': {('PMC4706275', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706280', 'c'),
#   ('PMC4706285', 'c')},
#  'errors': {('PMC4706275', 'c')},
#  'theoretical': {('PMC4706275', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779110', 'c')},
#  'shaded': {('PMC4706275', 'c'), ('PMC4706292', 'c')},
#  'bins': {('PMC4706275', 'c')},
#  'bin': {('PMC4706275', 'c')},
#  'figures': {('PMC4706275', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779099', 'c')},
#  'plot': {('PMC4706275', 'c'),
#   ('PMC4706278', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779094', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7583549', 'c')},
#  'percentage': {('PMC4706275', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7282159', 'c')},
#  'typical': {('PMC4706275', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779111', 'c')},
#  'hypogonadism': {('PMC4706275', 'c')},
#  'digestion': {('PMC4706280', 't'), ('PMC4706287', 'c')},
#  'load': {('PMC4706280', 't'), ('PMC7282150', 'c')},
#  'halofantrine': {('PMC4706280', 't')},
#  'absorption': {('PMC4706280', 't'),
#   ('PMC4706292', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779112', 'c')},
#  'nanoemulsifying': {('PMC4706280', 't'), ('PMC4706287', 'c')},
#  'delivery': {('PMC4706280', 't'),
#   ('PMC4706287', 'c'),
#   ('PMC4706287', 't'),
#   ('PMC4779090', 't'),
#   ('PMC4779100', 'c'),
#   ('PMC7583548', 't')},
#  'fatty': {('PMC4706280', 'c'), ('PMC7583549', 'c')},
#  'acids': {('PMC4706280', 'c')},
#  'generated': {('PMC4706280', 'c')},
#  'hydrolysis': {('PMC4706280', 'c')},
#  'lipids': {('PMC4706280', 'c'), ('PMC7282148', 'c')},
#  'snedds': {('PMC4706280', 'c')},
#  'super': {('PMC4706280', 'c')},
#  'orlistat': {('PMC4706280', 'c')},
#  'dynamic': {('PMC4706276', 'c'), ('PMC4706280', 'c'), ('PMC4779103', 'c')},
#  'lipolysis': {('PMC4706280', 'c')},
#  'pellet': {('PMC4706280', 'c')},
#  'aqueous': {('PMC4706280', 'c')},
#  'zero': {('PMC4706280', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC7583549', 'c')},
#  'sem': {('PMC4706280', 'c'),
#   ('PMC4779103', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7583548', 'c')},
#  'obtained': {('PMC4706280', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779111', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'rats': {('PMC4706280', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779099', 'c'),
#   ('PMC4779099', 't'),
#   ('PMC4779114', 'c'),
#   ('PMC7583549', 'c')},
#  'balance': {('PMC4706276', 't')},
#  'semiparametric': {('PMC4706276', 't')},
#  'approach': {('PMC4706276', 't'), ('PMC4779106', 'c'), ('PMC4779113', 'c')},
#  'evaluate': {('PMC4706276', 't'), ('PMC4779104', 'c')},
#  'neonatal': {('PMC4706276', 't'), ('PMC4779100', 't')},
#  'erythropoiesis': {('PMC4706276', 't')},
#  'present': {('PMC4706274', 'c'), ('PMC4706276', 'c')},
#  'circulation': {('PMC4706276', 'c'), ('PMC4779110', 'c')},
#  'month': {('PMC4706276', 'c'), ('PMC4706285', 'c')},
#  'sum': {('PMC4706276', 'c'), ('PMC4706292', 'c'), ('PMC4779109', 'c')},
#  'transfused': {('PMC4706276', 'c')},
#  'utero': {('PMC4706276', 'c')},
#  'birth': {('PMC4706276', 'c')},
#  'remaining': {('PMC4706276', 'c')},
#  'accounting': {('PMC4706276', 'c')},
#  'phlebotomy': {('PMC4706276', 'c')},
#  'loss': {('PMC4706276', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7282159', 't'),
#   ('PMC7583549', 'c')},
#  'difference': {('PMC4706276', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779113', 'c')},
#  'iman': {('PMC4706276', 'c')},
#  'conover': {('PMC4706276', 'c')},
#  'nonparametric': {('PMC4706276', 'c')},
#  'subsequent': {('PMC4706276', 'c')},
#  'cubic': {('PMC4706276', 'c')},
#  'spline': {('PMC4706276', 'c')},
#  'estimated': {('PMC4706276', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779091', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779113', 'c')},
#  'calculated': {('PMC4706274', 'c'), ('PMC4706276', 'c'), ('PMC4779096', 'c')},
#  'final': {('PMC4706276', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC7583549', 'c')},
#  'cumulative': {('PMC4706276', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779109', 'c')},
#  'amounts': {('PMC4706276', 'c'), ('PMC4779099', 'c')},
#  'smoothing': {('PMC4706276', 'c')},
#  'function': {('PMC4706276', 'c'), ('PMC4706292', 'c'), ('PMC7583549', 'c')},
#  'postnatal': {('PMC4706276', 'c')},
#  'production': {('PMC4706276', 'c'), ('PMC7583549', 'c')},
#  'four': {('PMC4706276', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779102', 'c'),
#   ('PMC4779106', 'c'),
#   ('PMC4779109', 'c'),
#   ('PMC4779113', 'c')},
#  'week': {('PMC4706276', 'c')},
#  'vlbw': {('PMC4706276', 'c')},
#  'elbw': {('PMC4706276', 'c')},
#  'anemic': {('PMC4706276', 'c')},
#  'preterm': {('PMC4706276', 'c'), ('PMC4779094', 't')},
#  'study': {('PMC4706276', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779096', 'c'),
#   ('PMC4779101', 'c'),
#   ('PMC4779110', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC4779113', 'c'),
#   ('PMC7583548', 'c'),
#   ('PMC7583549', 'c')},
#  'infants': {('PMC4706276', 'c'), ('PMC4706285', 't')},
#  'interactions': {('PMC4706279', 't')},
#  'long': {('PMC4706279', 'c'),
#   ('PMC4706279', 't'),
#   ('PMC4706287', 'c'),
#   ('PMC4779100', 't'),
#   ('PMC7282159', 'c')},
#  'half': {('PMC4706279', 'c'),
#   ('PMC4706279', 't'),
#   ('PMC4706285', 'c'),
#   ('PMC4706291', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779112', 'c'),
#   ('PMC7583549', 'c')},
#  'need': {('PMC4706274', 'c'), ('PMC4706279', 't'), ('PMC4706292', 'c')},
#  'illustration': {('PMC4706279', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779104', 'c'),
#   ('PMC7583549', 'c')},
#  'designs': {('PMC4706279', 'c'), ('PMC4779113', 'c')},
#  'evaluated': {('PMC4706279', 'c'), ('PMC4779113', 'c')},
#  'ddis': {('PMC4706279', 'c')},
#  'ddi': {('PMC4706279', 'c')},
#  'nca': {('PMC4706279', 'c')},
#  'scenarios': {('PMC4706279', 'c'), ('PMC4779102', 'c')},
#  'true': {('PMC4706279', 'c'), ('PMC4779108', 'c'), ('PMC4779113', 'c')},
#  'average': {('PMC4706279', 'c'), ('PMC4779104', 'c'), ('PMC4779113', 't')},
#  'scenario': {('PMC4706279', 'c')},
#  'inter': {('PMC4706279', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779112', 'c')},
#  'quartile': {('PMC4706279', 'c')},
#  'range': {('PMC4706274', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC7583549', 'c')},
#  'precision': {('PMC4706279', 'c'), ('PMC7583549', 'c')},
#  'quantified': {('PMC4706279', 'c')},
#  'estimate': {('PMC4706279', 'c')},
#  'describing': {('PMC4706279', 'c')},
#  'bdq': {('PMC4706279', 'c')},
#  '100': {('PMC4706274', 'c'),
#   ('PMC4706279', 'c'),
#   ('PMC4706281', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4706287', 'c'),
#   ('PMC4706292', 'c'),
#   ('PMC4779114', 'c'),
#   ('PMC7282159', 'c'),
#   ('PMC7583549', 'c')},
#  'trials': {('PMC4706279', 'c'), ('PMC4779113', 'c')},
#  'box': {('PMC4706279', 'c'),
#   ('PMC4706285', 'c'),
#   ('PMC4779108', 'c'),
#   ('PMC4779110', 'c')},
#  'estimation': {('PMC4706279', 'c'), ('PMC4779112', 'c'), ('PMC7583548', 'c')},
#  'interaction': {('PMC4706279', 'c')},
#  'parametric': {('PMC4706279', 'c')},
#  'gmrs': {('PMC4706279', 'c')},
#  'impact': {('PMC4706279', 'c'),
#   ('PMC4779090', 'c'),
#   ('PMC4779091', 't'),
#   ('PMC4779102', 'c'),
#   ('PMC4779104', 'c')},
#  'light': {('PMC4706279', 'c')},
#  'thermosensitive': {('PMC4706291', 't')},
#  'hydrogel': {('PMC4706291', 'c'), ('PMC4706291', 't')},
#  'gold': {('PMC4706291', 'c'), ('PMC4706291', 't')},
#  ...}

# %%
termInvIdx['biopsy']
# Out:
# {('PMC7282159', 'c')}

# %%
# Boolean operations:
def orPostings(posting1, posting2):
    p1 = 0
    p2 = 0
    result = list()
    n1 = len(posting1)
    n2 = len(posting2)
    while p1 < n1 and p2 <n2:
        if posting1[p1] == posting2[p2]:
            result.append(posting1[p1])
            p1 += 1
            p2 += 1
        elif posting1[p1] >posting2[p2]:
            result.append(posting2[p2])
            p2 += 1
        else:
            result.append(posting1[p1])
            p1 += 1
    while p1 < n1:
        result.append(posting1[p1])
        p1 += 1
    while p2 < n2:
        result.append(posting2[p2])
        p2 += 1
    return result

def andPostings(posting1, posting2):
    p1 = 0
    p2 = 0
    n1 = len(posting1)
    n2 = len(posting2)
    result = list()
    
    while p1 < n1 and p2 < n2:
        if posting1[p1] == posting2[p2]:
            result.append(posting1[p1])
            p1 += 1
            p2 += 1
        elif posting1[p1] > posting2[p2]:
            p2 += 1
        else:
            p1 += 1
            
    return result

# %%
pl_1 = list(termInvIdx['biopsy'])
pl_2 = list(termInvIdx['tissues'])

#pl_3 = list(termInvIdx['histopatology'])
#pl_4 = list(termInvIdx['photomicrographs'])


pl_5 = list(termInvIdx['case'])
pl_6 = list(termInvIdx['report'])

orPostings(pl_1, pl_2)
# Out:
# [('PMC4706283', 'c'), ('PMC7282159', 'c')]

# %%
andPostings(pl_5, pl_6)
# Out:
# [('PMC7583549', 'c'), ('PMC4706292', 'c')]

# %%
orPostings(orPostings(pl_1, pl_2), andPostings(pl_5, pl_6))
# Out:
# [('PMC4706283', 'c'),
#  ('PMC7282159', 'c'),
#  ('PMC7583549', 'c'),
#  ('PMC4706292', 'c')]
